# %%
import gc
import json
import time

import numpy as np
import pandas as pd
from mypackage.common_tools import *
import phonenumbers
from phonenumbers import PhoneNumber
from multiprocessing import Pool,Process,Queue,Manager,resource_tracker
from collections import defaultdict
import gc
import asyncio
import  traceback
from joblib import Parallel, delayed
from datetime import datetime
# 遍历文件夹sms_url的文件，文件名格式为raw_sms2023-06-01/raw_sms2024-07-01，按月份统计逾期率
import os
import re

# %%
from pathlib import Path
raw_dir = Path('/home/longxiaolei/raw_mx/newcust')
work_dir = Path('/home/mayongzhi/marshall/sender_word_call_app')

# %%
def get_res_from_proc(pid):
    try:
        with open(f'/proc/{pid}/statm', 'r') as f:
            data = f.read().split() 
            res = data[1]  # 第二个字段是 RES
            # 转成GB
            res = int(res) * 4 / (1024 * 1024)
            return res
    except FileNotFoundError:
        print(f"PID {pid} not found.")
    except Exception as e:
        print(f"Error reading /proc: {e}")
    return None

# %%
def parse_json_data(df, json_column, id_column, retain_column=None):
    """
    将df中的json字符串的摊平，并根据想要保留的字段，保留相关的值
    :param df:  待摊平处理的dataframe
    :param json_column: json字符串所在的那一列
    :param id_column: 唯一关联主键，后续用于定位转化失败的数据，或外部唯一关联的id
    :param retain_column: 待保留的列，可以是字符串，也可以是数组保存多列
    :return:
    """
    new_rows = []
    for i, row in df.iterrows():
        json_data_str = row[json_column]
        id_column_value = row[id_column]
        if isinstance(json_data_str, str):
            try:
                json_data = json.loads(json_data_str)
                for item in json_data:
                    new_row = item
                    new_row[id_column] = id_column_value
                    if isinstance(retain_column, str) and len(retain_column) > 0:
                        new_row[retain_column] = row[retain_column]
                    elif isinstance(retain_column, list) and len(retain_column) > 0:
                        for column in retain_column:
                            new_row[column] = row[column]
                    new_rows.append(new_row)
            except json.JSONDecodeError:
                print(f"Failed to parse JSON data for {id_column}:{id_column_value}")
                continue
    return pd.DataFrame(new_rows)

# %%
def data_of_dir(dir_path: str, contains_flags="", start_date='2023-01-01', end_date='2999-01-01'):
    def _fetch_filenams(dir_path: str, contain_flag, start_date=None, end_date=None):
        file_paths = []
        contain_flag = contain_flag or ""
        pattern = r"\d{4}-\d{2}-\d{2}"
        for file_name in os.listdir(dir_path):
            if (contain_flag in file_name) and (
            file_name.endswith(('.pqt', '.parquet', '.csv', '.xlsx', '.pickle', '.pkl'))):
                if start_date is None:
                    file_paths.append(os.path.join(dir_path, file_name))
                else:
                    match = re.search(pattern, file_name)
                    date = match.group()  # type: ignore
                    if (date >= start_date) and (date < end_date):
                        file_paths.append(os.path.join(dir_path, file_name))
        file_paths.sort()
        return file_paths

    if isinstance(contains_flags, str) or contains_flags is None:
        return _fetch_filenams(dir_path, contains_flags, start_date, end_date)
    elif isinstance(contains_flags, list):
        file_names = None
        for contains_flag in contains_flags:  # type: ignore
            if file_names is None:
                file_names = _fetch_filenams(dir_path, contains_flag, start_date, end_date)
            else:
                file_names = file_names + _fetch_filenams(dir_path, contains_flag, start_date, end_date)
        return file_names

# %%
def month_window(month_list:list[str],window_size:int):
    from dateutil.relativedelta import relativedelta
    date_objects = [datetime.strptime(date, '%Y-%m') for date in month_list]
    results = []
    for date in date_objects:
        end_month = date - relativedelta(months=1)
        start_month = date - relativedelta(months=window_size)
        results.append((date.strftime('%Y-%m'),end_month.strftime('%Y-%m'),start_month.strftime('%Y-%m')))
    return results

# %%
def parallel_process(task_function,task_list,process_num=10):
    start_time = time.time()
    def _task(task_function,queue,task_params):
        try:
            task_function(*task_params)
        finally:
            queue.put(True)
    from multiprocessing import Queue, Process
    mp_queue = Queue()
    for i in range(process_num):
        mp_queue.put(True)
    for task_params in tqdm(task_list):
        mp_queue.get()
        Process(target=_task,args=(task_function,mp_queue,task_params)).start()
    for i in range(process_num):
        mp_queue.get()
    mp_queue.close()
    gc.collect()
    print(f'任务完成，总计{len(task_list)}个任务,耗时{time.time()-start_time}s')

# %% [markdown]
# # 提取phone的逻辑
# 1. 保留字母型号码
# 2. 查看是否有以‘+’开头且包含字母的号码
# 3. 将以‘+’开头且不包含字母的号码和纯数字号码进行phone_normalize验证

# %%
def normalize_phone(phone, country_id):
    # 去掉phone中的非数字和非字母
    def phone_normalize(phone):
        if len(phone) == 0 or phone is None:
            return 0, '', ''
        if phone[0] == '+':
            phone = '+' + phone.replace('+', '').lstrip('0')
            length = len(phone) - 1
        else:
            phone = phone.lstrip('0')
            length = len(phone)
        is_vaild, country_code, national_phone = 0, '', phone.lstrip('+')

        if length < 7:
            return str(national_phone)

        try:
            if phone.startswith('+'):
                parse_info = phonenumbers.parse(phone)
            else:
                parse_info = phonenumbers.parse(phone, country_id.upper())

            # print(phonenumbers.is_valid_number(parse_info))
            is_vaild = 1 if phonenumbers.is_valid_number(parse_info) else 0
            if is_vaild:
                # country_code = parse_info.country_code
                national_phone = parse_info.national_number
                return str(national_phone)
        except Exception:
            pass
        return str(national_phone)

    phone = str(phone)
    try:
        if len(phone) == 0 or phone is None:
            return ''
        if phone[0] == '+':
            phone = '+' + ''.join(filter(str.isalnum, phone[1:])).lower()
        else:
            phone = ''.join(filter(str.isalnum, phone)).lower()  # 去掉phone中的非数字和非字母
    except Exception as e:
        pass
    if any(c.isalpha() for c in phone):
        return phone.replace('+', '')
    return phone_normalize(phone)

# %% [markdown]
# # data_sample处理过程
# 1. 每一行parse_json_data提取出'src_phone'、'app_order_id'、'apply_time'、'agr_pd7'、'def_pd7'列
# 2. 对'src_phone'列的数据进行normalize_phone处理，将结果存入parse后的'national_phone'列
# 3. 统计'national_phone'列的数据

# %% [markdown]
# # 按月份统计逾期率

# %% [markdown]
# $ phone_i\_overdue\_rate = \frac{\frac{Bad\_Count_i}{Total\_Count_i}} {\frac{Bad\_label}{Total\_label}} $

# %% [markdown]
# # sender

# %%
def get_senders(sms_data):
    """
    获取每行的phone
    :param sms_data: df 中的'sms_data'列
    :return: 
    """
    # row = pd.DataFrame(row).T
    # print(row)
    # 如果‘sms_data'列为空或者为'[]'，则返回空字典
    
    if sms_data == '[]' or sms_data == '' or sms_data is None:
        return []
    parse_df = pd.DataFrame(json.loads(sms_data))
    if 'src_phone' not in parse_df.columns:
        print('src_phone not in columns')
        return []
    # if len(parse_df[parse_df['src_phone'].str.len()>30]) > 0:
    #     print(parse_df[parse_df['src_phone'].str.len()>30]['src_phone'])
    parse_df['national_phone'] = parse_df['src_phone'].apply(lambda x: normalize_phone(x,'MX'))
    senders = parse_df['national_phone'].tolist()
    return senders

# %%
def generate_month_sender_config(file_path=None, month=None, sender_data=None):
    """
    生成某个月sender逾期率文件
    :param file_path: 生成配置文件的文件路径
    :param month: 月份,'YYYY-MM'
    :param sender_data: 如果sender_data不为空，则直接使用sender_data
    :return: 
    """
    tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')
    if not os.path.exists(tmp_dir):
        os.makedirs(tmp_dir)
    # 确保当sender_data不为空时，file_path和month为空，反之亦然
    assert (sender_data is None) != (file_path is None and month is None), "if sender_data is not None, file_path and month should be None and vice versa"
    if sender_data is None:
        file_names = os.listdir(file_path)

        month_files = defaultdict(list)
        for file_name in file_names:
            file_name = file_path / file_name
            match = re.search(r'(\d{4}-\d{2})',str(file_name))
            if match and match.group() == month:
                month_files[month].append(str(file_name))
        files = month_files[month]
        print(files)
        sender_data = batch_load_files_to_df(files)
    sender_data = sender_data[['sms_data','def_pd7','agr_pd7']] 
    sender_data['bad'] = np.where(sender_data['agr_pd7'] == 1, sender_data['def_pd7'], None)
    sender_data = sender_data[sender_data['bad'].notnull()]
    bad_rate_total = sender_data['bad'].mean()

    df_month_sender = pd.DataFrame()
    df_month_sender['sender'] = Parallel(n_jobs=10)(delayed(get_senders)(sms_data) for sms_data in sender_data['sms_data'])
    df_month_sender['def_pd7'] = sender_data['def_pd7']
    df_month_sender = df_month_sender.explode('sender')
    df_month_sender = df_month_sender[df_month_sender['sender'].apply(lambda x: isinstance(x, str))]
    
    print(df_month_sender.shape)
    overdue_rate_df = df_month_sender.groupby('sender')['def_pd7'].agg(['sum','count']).reset_index()
    overdue_rate_df = overdue_rate_df.rename(columns={'sum':'bad_count','count':'total_count'})
    overdue_rate_df['bad_rate_total'] =  bad_rate_total
    overdue_rate_df['bad_rate'] = overdue_rate_df['bad_count'] / overdue_rate_df['total_count']
    
    print(month)
    print(overdue_rate_df.shape)
    print('before:',get_res_from_proc(os.getpid()))
    # 释放内存
    del df_month_sender, sender_data
    gc.collect()
    print('after:',get_res_from_proc(os.getpid()))
    overdue_rate_df.to_parquet(tmp_dir / f'sender_overdue_rate_{month}.parquet',compression='zstd')
    return overdue_rate_df

# %%
tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')
if not os.path.exists(tmp_dir):
    os.makedirs(tmp_dir)

# %%
for month in ['2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
    overdue_rate_config = generate_month_sender_config(file_path=raw_dir,month=month)
    overdue_rate_config.to_parquet(f'sender_overdue_rate_{month}.parquet',compression='zstd')
# Out:
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-27.pqt']
# (27779809, 2)
# 2023-08
# (772784, 5)
# before: 27.019664764404297
# after: 26.306224822998047
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-26.pqt']
# (28305013, 2)
# 2023-09
# (910512, 5)
# before: 40.27848434448242
# after: 39.530052185058594
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-31.pqt']
# (32678982, 2)
# 2023-10
# (1090530, 5)
# before: 50.36192321777344
# after: 49.17375946044922
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-27.pqt', '/home/longxiaolei/raw_m ...
# (32151030, 2)
# 2023-11
# (1233865, 5)
# before: 53.74588394165039
# after: 52.92097473144531
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-21.pqt', '/home/longxiaolei ...
# (31997448, 2)
# 2023-12
# (1196249, 5)
# before: 58.4575309753418
# after: 57.60071563720703
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-20.pqt', '/home/longxiaole ...
# (27524349, 2)
# 2024-01
# (1124108, 5)
# before: 60.13999938964844
# after: 59.31282424926758
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-23.pqt', '/home/longxiaolei/r ...
# (25652248, 2)
# 2024-02
# (1032320, 5)
# before: 61.08218002319336
# after: 60.49245834350586
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-20.pqt', '/home/longxiaole ...
# (22737214, 2)
# 2024-03
# (1023235, 5)
# before: 61.26951599121094
# after: 60.65000915527344
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-21.pqt', '/home/longxiaolei ...
# (21543343, 2)
# 2024-04
# (1047051, 5)
# before: 62.448944091796875
# after: 61.80057144165039
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-20.pqt', '/home/longxiaol ...
# (32209123, 2)
# 2024-05
# (1588662, 5)
# before: 66.70669174194336
# after: 65.7895622253418
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-21.pqt', '/home/longxiaolei ...
# (53210112, 2)
# 2024-06
# (2739709, 5)
# before: 95.75735855102539
# after: 93.66939544677734
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-21.pqt', '/home/longxiaolei ...
# (35341378, 2)
# 2024-07
# (2221689, 5)
# before: 99.17660522460938
# after: 97.99848556518555
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-16.pqt']
# (5639498, 2)
# 2024-08
# (636996, 5)
# before: 98.72854232788086
# after: 98.34707641601562

# %%
check = pd.read_parquet('sender_overdue_rate_2023-06.parquet')
check.head()
# Out:
#   sender  bad_count  total_count  bad_rate       woe
# 0                57          117  0.487179  0.075665
# 1      1          7            9  0.777778  1.379720
# 2     10          1            1  1.000000  0.000000
# 3    100          0            7  0.000000  0.000000
# 4   1000          2            2  1.000000  0.000000

# %%
# sender_overdue_rate_2024_07  文件大小，单位为MB
os.path.getsize('sender_overdue_rate_2024-07.parquet') / 1024 / 1024
# Out:
# 11.449203491210938

# %%
def parallel_process(task_function,task_list,process_num=10):
    """
    task_function : 任务函数
    task_list : 任务列表
    """
    start_time = time.time()
    def _task(task_function,queue,task_params):
        try:
            task_function(*task_params)
        finally:
            queue.put(True)
    from multiprocessing import Queue, Process
    mp_queue = Queue()
    for i in range(process_num):
        mp_queue.put(True)
    for task_params in tqdm(task_list):
        mp_queue.get()
        Process(target=_task,args=(task_function,mp_queue,task_params)).start() # mq_queue 用于控制进程数
        # 完成后kill掉进程
        process_id = os.getpid()
        os.system(f'kill -9 {process_id}')
    for i in range(process_num):
        mp_queue.get()
    mp_queue.close()
    gc.collect()
    print(f'任务完成，总计{len(task_list)}个任务,耗时{time.time()-start_time}s')

# %% [markdown]
# # words

# %%
# 西班牙语停用词
# import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('spanish'))
# 添加自定义停用词
user_stop_words = ['body','phone', 'src_phone', 'read', 'time', 'type']
stop_words.update(user_stop_words)
print(stop_words)
print('body' in stop_words)
len(stop_words)
# Out:
# {'son', 'entre', 'sus', 'estando', 'tuyas', 'serás', 'seas', 'estuvo', 'tenido', 'tendrá', 'tuviéramos', 'ante', 'fuimos', 'type', 'seré', 'fuesen', 'vuestros', 'ese', 'tengamos', 'uno', 'vosotros', 'desde', 'eso', 'tenía', 'tendríamos', 'durante', 'las', 'todo', 'hubieran', 'mío', 'unos', 'tendréis', 'antes', 'estábamos', 'nosotros', 'fue', 'somos', 'tuvieseis', 'sintiendo', 'le', 'ellos', 'estén', 'estaréis', 'serías', 'tendremos', 'estaríamos', 'fuésemos', 'tiene', 'habrán', 'seremos', 'fuera', 'time', 'estés', 'contra', 'serían', 'sentidos', 'nada', 'muy', 'tuvieras', 'tuve', 'tengan', 'estarán', 'un', 'quien', 'otro', 'fueras', 'vuestras', 'sois', 'tuvieran', 'serán', 'estamos', 'teníais', 'hubiesen', 'estaría', 'es', 'habían', 'tengo', 'estarás', 'otras', 'eres', 'body', 'tendrían', 'su', 'de', 'estás', 'habríamos', 'como', 'tú', 'eran', 'fueran', 'seríamos', 'he', 'seríais', 'el', 'otros', 'hemos', 'estas', 'tenida', 'erais', 'los', 'hubo', 'habidos', 'tienen', 'estuvieron', 'suyos', 'estabais', 'sentido', 'tenían', 'sí', 'habíais', 'la', 'tienes', 'esté', 'estaremos', 'estos', 'mucho', 'estuvimos', 'muchos', 'tuya', 'con', 'nuestros', 'tanto', 'todos', 'nuestras', 'habríais', 'tuviésemos', 'esa', 'ya', 'que', 'tenidos', 'ha', 'otra', 'sean', 'ella', 'estar', 'suyas', 'tuvimos', 'hubiéramos', 'estaré', 'fuese', 'habíamos', 'tuyos', 'estaban', 'hubisteis', 'seréis', 'suyo', 'algo', 'tendrán', 'hayamos', 'fueses', 'estuviese', 'tus', 'estarían', 'estemos', 'tuviese', 'habrá', 'sea', 'seáis', 'teníamos', 'tendríais', 'sin', 'hubiese', 'tendrás', 'esto', 'sobre', 'este', 'les', 'será', 'estáis', 'por', 'habremos', 'estados', 'habido', 'tendré', 'esas', 'nosotras', 'habrás', 'estadas', 'fui', 'ellas', 'a', 'estada', 'mías', 'vosotras', 'fuisteis', 'éramos', 'habrías', 'estuviésemos', 'fuéramos', 'haya', 'hubieseis', 'tenga', 'nuestro', 'yo', 'más', 'nos', 'porque', 'cual', 'fueron', 'hayáis', 'teniendo', 'o', 'estuvieras', 'seamos', 'estéis', 'ti', 'estuviesen', 'hubieras', 'tuvierais', 'hayas', 'tened', 'poco', 'tu', 'os', 'habida', 'nuestra', 'fuerais', 'hubiera', 'esos', 'estarías', 'habiendo', 'algunas', 'tuyo', 'has', 'cuando', 'están', 'suya', 'estará', 'lo', 'era', 'han', 'habrían', 'hayan', 'fueseis', 'habéis', 'habré', 'estuvieseis', 'habías', 'estaba', 'te', 'hasta', 'hubieron', 'estoy', 'una', 'src_phone', 'y', 'habidas', 'tenidas', 'tengas', 'estaríais', 'también', 'phone', 'hubimos', 'estuviera', 'tengáis', 'mis', 'sentidas', 'tenéis', 'algunos', 'vuestra', 'estad', 'tuvo', 'qué', 'estuviéramos', 'hay', 'tenías', 'hubiste', 'estado', 'soy', 'estuve', 'tuvieron', 'vuestro', 'hubieses', 'read', 'tuvieses', 'sentida', 'al', 'mí', 'estuvisteis', 'estuviste', 'tuviera', 'estuvierais', 'había', 'hubiésemos', 'hube', 'tendría', 'siente', 'eras', 'está', 'para', 'se', 'habréis', 'tuviste', 'estuvieses', 'fuiste', 'estuvieran', 'esta', 'tenemos', 'mi', 'me', 'no', 'habría', 'estabas', 'él', 'hubierais', 'tendrías', 'del', 'e', 'quienes', 'sería', 'donde', 'mía', 'míos', 'tuviesen', 'en', 'sentid', 'tuvisteis', 'ni', 'pero'}
# True
# 319

# %%
from concurrent.futures import ProcessPoolExecutor
# parse后统计‘body’列的词频
from collections import Counter
# 并行处理

def get_words(sms_data):
    """
    获取每行的word
    :param sms_data: df 中的'sms_data'列
    :return: 根据sms_data提取的word
    """
    if sms_data == '[]' or sms_data == '' or sms_data is None:
        return []
    parse_df = pd.DataFrame(json.loads(sms_data))
    if 'body' not in parse_df.columns:
        print('body not in columns','id:')
        return []
    
    words = parse_df['body'].apply(lambda x: set(re.compile(r'\b[Ññáéíóú¡a-z]+\b').findall(x.lower() if isinstance(x,str) else '')).difference(stop_words))
    words = words.apply(lambda x:list(filter(lambda x: len(x) > 2, x)))
    words = set(sum(words.tolist(),[]))
    words = list(words)
    return words
    
def generate_month_word_config(file_path=None, month=None, word_data=None):
    """
    生成某个月word逾期率文件
    :param file_path: 生成配置文件的文件路径
    :param month: 月份
    :param word_data: 如果word_data不为空，则直接使用word_data
    """
    try:
        tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')
        assert (word_data is None) != (file_path is None and month is None), "if word_data is not None, file_path and month should be None and vice versa"
        if word_data is None:
            file_names = os.listdir(file_path)
            
            month_files = defaultdict(list)
            for file_name in file_names:
                manager = Manager()
                file_names = os.listdir(file_path)

                month_files = defaultdict(list)
                for file_name in file_names:
                    file_name = file_path / file_name
                    match = re.search(r'(\d{4}-\d{2})',str(file_name))
                    if match and match.group() == month:
                        month_files[month].append(str(file_name))
            files = month_files[month]
            print(files)
            word_data = batch_load_files_to_df(files)
        word_data = word_data[['sms_data','def_pd7','agr_pd7']]
        word_data['bad'] = np.where(word_data['agr_pd7'] == 1, word_data['def_pd7'], None)
        word_data = word_data[word_data['bad'].notnull()]
        bad_rate_total = word_data['bad'].mean()
        
        df_month_word = pd.DataFrame()
        df_month_word['word'] = Parallel(n_jobs=15)(delayed(get_words)(sms_data) for sms_data in word_data['sms_data'])
        df_month_word['def_pd7'] = word_data['def_pd7']
        df_month_word = df_month_word.explode('word')
        df_month_word = df_month_word[df_month_word['word'].apply(lambda x: isinstance(x, str))]
        print(df_month_word.shape)
        overdue_rate_df = df_month_word.groupby('word')['def_pd7'].agg(['sum','count']).reset_index()
        overdue_rate_df = overdue_rate_df.rename(columns={'sum':'bad_count','count':'total_count'})
        overdue_rate_df['bad_rate_total'] =  bad_rate_total
        overdue_rate_df['bad_rate'] = overdue_rate_df['bad_count'] / overdue_rate_df['total_count']
        overdue_rate_df.to_parquet(tmp_dir / f'word_overdue_rate_{month}.parquet',compression='zstd')
        # del df_month_word, word_data, overdue_rate_df
        # gc.collect()
        return 0
    except Exception as e:
        print(f"Error: {e}, month: {month}",traceback.format_exc())
        return 1
    # return overdue_rate_df

# %%
for month in ['2024-06','2024-07','2024-08']:
    generate_month_word_config(file_path=raw_dir,month=month)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for month in ['2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
# ----> 2     generate_month_word_config(file_path=raw_dir,month=month)
#
# Cell In[10], line 43, in generate_month_word_config(file_path, month, word_data)
#      40 manager = Manager()
#      41 file_names = os.listdir(file_path)
# ---> 43 month_files = defaultdict(list)
#      44 for file_name in file_names:
#      45     file_name = file_path / file_name
#
# KeyboardInterrupt:

# %%
print('a')

# %%
months = ['2024-06','2024-07','2024-08']
task_list = [(raw_dir,month) for month in months]
parallel_process(generate_month_word_config,task_list,process_num=2)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-21.pqt', '/home/longxiaolei ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-21.pqt', '/home/longxiaolei ...
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49315_65b6160596ff48cc9a532dd27db19b9e_48056100485b43d4966a61f708ac2f7d: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49315_65b6160596ff48cc9a532dd27db19b9e_49f68da4f5874a0db9933c90bbb7688d: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49314_34eb0a1cb35d485a8c94663444457922_8b3e311352ab4b3aa610f374b3c3d044: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49314_34eb0a1cb35d485a8c94663444457922_91923cb8a3bd446290935e683531d927: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49715_6ac17d6f7e1f4ca4a50fd83016954c22_d16d10dcae8d4965a03e0f91f6283878: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49715_6ac17d6f7e1f4ca4a50fd83016954c22_154e482ebe9e4e258feb067f7db36f82: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49849_a8c23c7c477e4d94a0c69f65f2343c12_d4626e5a2f8740f18fbb1634cb1158fd: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_49849_a8c23c7c477e4d94a0c69f65f2343c12_36079c06cab0451f81aac4cdabf4e633: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50090_7936701a4d9c4eb38ae7c0eb47161817_e70f27da20af4612ba21bde8444fee1f: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50090_7936701a4d9c4eb38ae7c0eb47161817_65022700ec5548d8b2a1506ba68554b8: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50302_85e90b8dbf834f1893e00ffa74845c15_5d180e508d2445e6bba55ee3599e6174: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50302_85e90b8dbf834f1893e00ffa74845c15_6595da1b2a9642b787c36622e4beb87c: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# (68232189, 2)
# 进程50682完成
# 100%|██████████| 3/3 [15:35<00:00, 311.76s/it]
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-16.pqt']
# (10980181, 2)
# 进程61625完成
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 21 leaked semlock objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:310: UserWarning: resource_tracker: There appear to be 2 leaked folder objects to clean up at shutdown
#   warnings.warn(
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50682_59c006c5556740d7a4597f77fbb65314_ee615e99112f40a1ae4770185c182e53: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/joblib/externals/loky/backend/resource_tracker.py:326: UserWarning: resource_tracker: /tmp/joblib_memmapping_folder_50682_59c006c5556740d7a4597f77fbb65314_a3a09d1e65dd4276a1bb20714cb49b9b: FileNotFoundError(2, 'No such file or directory')
#   warnings.warn(f'resource_tracker: {name}: {e!r}')
# (105627345, 2)
# 进程50681完成
# 任务完成，总计3个任务,耗时1273.6771664619446s

# %% [markdown]
# ## check_word_config

# %%
word_config = pd.read_parquet(tmp_dir / 'word_overdue_rate_2023-06.parquet')
word_config['total_count'].describe()

# %%
for month in ['2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
    overdue_rate_config = generate_month_word_config(file_path=raw_dir,month=month)
    overdue_rate_config.to_parquet(f'word_overdue_rate_{month}.parquet',compression='zstd')

# %% [markdown]
# # applist

# %%
def get_apps(applist_data):
    """
    获取每行的app
    :param applist_data: df 中的'applist_data'列
    :return: 
    """
    if applist_data == '[]' or applist_data == '' or applist_data is None:
        return []
    parse_df = pd.DataFrame(json.loads(applist_data))
    if 'app_package' not in parse_df.columns:
        print('app_package not in columns')
        return []
    parse_df['app_package'] = parse_df['app_package'].apply(lambda x: x.lower() if isinstance(x,str) else '')
    apps = parse_df['app_package'].tolist()
    return apps

# %%
def generate_month_applist_config(file_path=None, month=None, applist_data=None):
    """
    生成某个月app逾期率文件
    :param file_path: 生成配置文件的文件路径
    :param month: 月份,'YYYY-MM'
    :param applist_data: 如果applist_data不为空，则直接使用applist_data
    :return: 
    """
    try:
        tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')
        assert (applist_data is None) != (file_path is None and month is None), "if applist_data is not None, file_path and month should be None and vice versa"
        if applist_data is None:
            file_names = os.listdir(file_path)
            month_files = defaultdict(list)
            for file_name in file_names:
                file_name = file_path / file_name   
                match = re.search(r'(\d{4}-\d{2})',str(file_name))
                if match and match.group() == month: 
                    month_files[month].append(str(file_name))
            files = month_files[month]
            print(files)
            applist_data = batch_load_files_to_df(files)
        applist_data = applist_data[['applist_data','def_pd7','agr_pd7']]
        applist_data['bad'] = np.where(applist_data['agr_pd7'] == 1, applist_data['def_pd7'], None)
        applist_data = applist_data[applist_data['bad'].notnull()]
        bad_rate_total = applist_data['bad'].mean()

        df_month_app = pd.DataFrame()
        df_month_app['app'] = Parallel(n_jobs=15)(delayed(get_apps)(applist_data) for applist_data in applist_data['applist_data'])
        df_month_app['def_pd7'] = applist_data['def_pd7']
        df_month_app = df_month_app.explode('app')
        print(df_month_app.shape)
        overdue_rate_df = df_month_app.groupby('app')['def_pd7'].agg(['sum','count']).reset_index()
        overdue_rate_df = overdue_rate_df.rename(columns={'sum':'bad_count','count':'total_count'})
        overdue_rate_df['bad_rate_total'] =  bad_rate_total
        overdue_rate_df['bad_rate'] = overdue_rate_df['bad_count'] / overdue_rate_df['total_count']
     
        print(month)
        print(overdue_rate_df.shape)
        # 释放内存
        del df_month_app, applist_data
        gc.collect()
        overdue_rate_df = overdue_rate_df[overdue_rate_df['app'].apply(lambda x: isinstance(x, str))]
        print(overdue_rate_df.shape)
        overdue_rate_df.to_parquet(tmp_dir / f'app_overdue_rate_{month}.parquet',compression='zstd')
        return 1
    except Exception as e:
        print(f"Error: {e}, month: {month}",traceback.format_exc())
        return 0

# %%
months = ['2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']
task_list = [(raw_dir,month) for month in months]
parallel_process(generate_month_applist_config,task_list,process_num=2)

# %%
for month in ['2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
    generate_month_applist_config(file_path=raw_dir,month=month)

# %%
overdue_rate_config_07 = generate_month_applist_config(file_path=raw_dir,month='2024-07')
overdue_rate_config_07.to_parquet('app_overdue_rate_2024-07.parquet',compression='zstd')
# Out:
# (9868965, 2)
# (56128, 3)

# %% [markdown]
# ##  case_check

# %% [markdown]
# # calllog

# %% [markdown]
# m:becallPhone, ym:becallPhone, am:call_log_number

# %%
manager = Manager()
file_names = os.listdir('sms_url')

month_files = defaultdict(list)
for file_name in file_names:
    file_name = 'sms_url/' + file_name
    try:
        month = re.findall(r'(\d{4}-\d{2})_\w+', file_name)
        # print(month)
        month = re.findall(r'(\d{4}-\d{2})_\w+', file_name)[0][:7]
        month_files[month].append(file_name)
    except:
        pass
        # print(file_name)
month_files
# Out:
# defaultdict(list,
#             {'2023-06': ['sms_url/2023-06_AM',
#               'sms_url/2023-06_YM',
#               'sms_url/2023-06_M'],
#              '2023-07': ['sms_url/2023-07_AM',
#               'sms_url/2023-07_YM',
#               'sms_url/2023-07_M'],
#              '2023-08': ['sms_url/2023-08_AM',
#               'sms_url/2023-08_YM',
#               'sms_url/2023-08_M'],
#              '2023-09': ['sms_url/2023-09_AM',
#               'sms_url/2023-09_YM',
#               'sms_url/2023-09_M'],
#              '2023-10': ['sms_url/2023-10_AM',
#               'sms_url/2023-10_YM',
#               'sms_url/2023-10_M'],
#              '2023-11': ['sms_url/2023-11_AM',
#               'sms_url/2023-11_YM',
#               'sms_url/2023-11_M'],
#              '2023-12': ['sms_url/2023-12_AM',
#               'sms_url/2023-12_YM',
#               'sms_url/2023-12_M'],
#              '2024-01': ['sms_url/2024-01_AM',
#               'sms_url/2024-01_YM',
#               'sms_url/2024-01_M'],
#              '2024-02': ['sms_url/2024-02_AM',
#               'sms_url/2024-02_YM',
#               'sms_url/2024-02_M'],
#              '2024-03': ['sms_url/2024-03_AM',
#               'sms_url/2024-03_YM',
#               'sms_url/2024-03_M'],
#              '2024-04': ['sms_url/2024-04_AM',
#               'sms_url/2024-04_YM',
#               'sms_url/2024-04_M'],
#              '2024-05': ['sms_url/2024-05_AM',
#               'sms_url/2024-05_YM',
#               'sms_url/2024-05_M'],
#              '2024-06': ['sms_url/2024-06_AM',
#               'sms_url/2024-06_YM',
#               'sms_url/2024-06_M'],
#              '2024-07': ['sms_url/2024-07_YM', 'sms_url/2024-07_AM']})

# %%
def extract_phone(data):
    if data is None or data == '[]':
        return set()
    entries = json.loads(data)
    phones = []
    for entry in entries:
        if 'becallPhone' in entry:
            phone = normalize_phone(entry.get('becallPhone'))
            if phone:
                phones.extend(phone)
        if 'call_log_number' in entry:
            phone = normalize_phone(entry.get('call_log_number'))
            if phone:
                phones.extend(phone)
    return set(phones)

def generate_month_calllog_config(month):
    """
    生成calllog配置文件：逾期率
    :param month: 
    :return: 
    """
    try:
        files = month_files[month]
        print(month)
        print(files)
        calllog_data = batch_load_files_to_df(files)
        calllog_data = calllog_data[calllog_data['agr_pd7'] == 1]
        month_overdue_rate = calllog_data['def_pd7'].mean()
        calllog_data = calllog_data[(calllog_data['call_records_url'].notnull()) & (calllog_data['call_records_url'] != '[]')]
        calllog_data['calllog'] = calllog_data['call_records_url_data'].apply(extract_phone)
        calllog_overdue_rate = {}
        for phones, label in zip(calllog_data['calllog'], calllog_data['def_pd7']):
            for phone in phones:
                phone = normalize_phone(str(phone))[-1]
                if phone not in calllog_overdue_rate:
                    calllog_overdue_rate[phone] = [0, 0, 0]
                if label == 1:
                    calllog_overdue_rate[phone][0] += 1
                calllog_overdue_rate[phone][1] += 1
                calllog_overdue_rate[phone][2] = round(calllog_overdue_rate[phone][0] / calllog_overdue_rate[phone][1], 4)
        overdue_rate_df = pd.DataFrame(calllog_overdue_rate).T
        overdue_rate_df.rename(columns={0: 'bad_count', 1: 'total_count', 2: 'rate'}, inplace=True)
        overdue_rate_df.sort_values('total_count', ascending=False, inplace=True)
        overdue_rate_df['woe'] = overdue_rate_df['rate'].apply(lambda x: x / month_overdue_rate)
        overdue_rate_df.reset_index(inplace=True)
        overdue_rate_df.rename(columns={'index':'phone'},inplace=True)
        overdue_rate_df['phone'] = overdue_rate_df['phone'].astype(str)
        overdue_rate_df.to_parquet(f'calllog_overdue_rate_{month}.parquet',compression='zstd')
        print(f"Finish processing {month}")
    except Exception as e:
        print(f"Error: {e}, month: {month}")
    finally:
        local_vars = list(locals().keys())
        for var in local_vars:
            del locals()[var]
        gc.collect()

for month in month_files.keys():
    generate_month_calllog_config(month)
# Out:
# 2023-06
# ['sms_url/2023-06_AM', 'sms_url/2023-06_YM', 'sms_url/2023-06_M']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/marshall/mypackage/common_tools.py:140, in batch_load_files_to_df(paths, file_type)
#     139 futures = {executor.submit(load_file_to_df, path, file_type): path for path in paths}
# --> 140 for future in as_completed(futures):
#     141     try:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 60
#      57         gc.collect()
#      59 for month in month_files.keys():
# ---> 60     generate_month_calllog_config(month)
#
# Cell In[14], line 27, in generate_month_calllog_config(month)
#      25 print(month)
#      26 print(files)
# ---> 27 calllog_data = batch_load_files_to_df(files)
#      28 calllog_data = calllog_data[calllog_data['agr_pd7'] == 1]
#      29 month_overdue_rate = calllog_data['def_pd7'].mean()
#
# File ~/marshall/mypackage/common_tools.py:138, in batch_load_files_to_df(paths, file_type)
#     131 """
#     132 并行批量加载文件
#     133 :param paths: 文件路径列表
#     134 :param file_type: 文件类型, 支持parquet,csv,pickle
#     135 :return: 合并后的dataframe
#     136 """
#     137 dfs = []
# --> 138 with ThreadPoolExecutor() as executor:
#     139     futures = {executor.submit(load_file_to_df, path, file_type): path for path in paths}
#     140     for future in as_completed(futures):
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:

# %%
files = month_files[month]
print(month)
print(files)
calllog_data = batch_load_files_to_df(files)
calllog_data = calllog_data[calllog_data['agr_pd7'] == 1]
calllog_data = calllog_data[(calllog_data['call_records_url'].notnull()) & (calllog_data['call_records_url'] != '[]')]
month_overdue_rate = calllog_data['def_pd7'].mean()
calllog_data['calllog'] = calllog_data['call_records_url_data'].apply(extract_phone)
calllog_overdue_rate = {}
for phones, label in zip(calllog_data['calllog'], calllog_data['def_pd7']):
    for phone in phones:
        phone = normalize_phone(str(phone))[-1]
        if phone not in calllog_overdue_rate:
            calllog_overdue_rate[phone] = [0, 0, 0]
        if label == 1:
            calllog_overdue_rate[phone][0] += 1
        calllog_overdue_rate[phone][1] += 1
        calllog_overdue_rate[phone][2] = round(calllog_overdue_rate[phone][0] / calllog_overdue_rate[phone][1], 4)
overdue_rate_df = pd.DataFrame(calllog_overdue_rate).T
overdue_rate_df.rename(columns={0: 'bad_count', 1: 'total_count', 2: 'rate'}, inplace=True)
overdue_rate_df.sort_values('total_count', ascending=False, inplace=True)
overdue_rate_df['woe'] = overdue_rate_df['rate'].apply(lambda x: x / month_overdue_rate)
overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')
print(f"Finish processing {month}")
# Out:
# 2023-07
# ['sms_url/2023-07_AM', 'sms_url/2023-07_YM', 'sms_url/2023-07_M']
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[11], line 23
#      21 overdue_rate_df.sort_values('total_count', ascending=False, inplace=True)
#      22 overdue_rate_df['woe'] = overdue_rate_df['rate'].apply(lambda x: x / month_overdue_rate)
# ---> 23 overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')
#      24 print(f"Finish processing {month}")
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:190, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     187 if index is not None:
#     188     from_pandas_kwargs["preserve_index"] = index
# --> 190 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     192 if df.attrs:
#     193     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/table.pxi:4525, in pyarrow.lib.Table.from_pandas()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:345, in pyarrow.lib.array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:85, in pyarrow.lib._ndarray_to_array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object')

# %%
calllog_data.shape
# Out:
# (5, 29)

# %%
overdue_rate_df.describe()
# Out:
#          bad_count  total_count         rate          woe
# count  1677.000000  1677.000000  1677.000000  1677.000000
# mean      0.494335     1.008348     0.489565     0.815941
# std       0.506047     0.114266     0.498846     0.831409
# min       0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     0.000000
# 50%       0.000000     1.000000     0.000000     0.000000
# 75%       1.000000     1.000000     1.000000     1.666667
# max       3.000000     4.000000     1.000000     1.666667

# %%
overdue_rate_df = overdue_rate_df.astype('float64')

# %%
overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:190, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     187 if index is not None:
#     188     from_pandas_kwargs["preserve_index"] = index
# --> 190 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     192 if df.attrs:
#     193     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/table.pxi:4525, in pyarrow.lib.Table.from_pandas()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:345, in pyarrow.lib.array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:85, in pyarrow.lib._ndarray_to_array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object')

# %%
overdue_rate_df.columns
# Out:
# Index(['bad_count', 'total_count', 'rate', 'woe'], dtype='object')

# %%
overdue_rate_df.reset_index(inplace=True)

# %%
overdue_rate_df.head()
# Out:
#         index  bad_count  total_count  rate       woe
# 0          86        2.0          4.0   0.5  0.833333
# 1  4429800292        3.0          3.0   1.0  1.666667
# 2  4734540036        1.0          2.0   0.5  0.833333
# 3  5544380802        1.0          2.0   0.5  0.833333
# 4  5592735569        1.0          2.0   0.5  0.833333

# %%
overdue_rate_df.dtypes
# Out:
# index           object
# bad_count      float64
# total_count    float64
# rate           float64
# woe            float64
# dtype: object

# %%
overdue_rate_df.isnull().sum()
# Out:
# index          0
# bad_count      0
# total_count    0
# rate           0
# woe            0
# dtype: int64

# %%
overdue_rate_df.rename(columns={'index':'phone'},inplace=True)
overdue_rate_df['phone'] = overdue_rate_df['phone'].astype(str)

# %%
print(overdue_rate_df.dtypes)
# Out:
# bad_count      float64
# total_count    float64
# rate           float64
# woe            float64
# dtype: object

# %%
overdue_rate_df.head()
# Out:
#             bad_count  total_count  rate       woe
# 86                2.0          4.0   0.5  0.833333
# 4429800292        3.0          3.0   1.0  1.666667
# 4734540036        1.0          2.0   0.5  0.833333
# 5544380802        1.0          2.0   0.5  0.833333
# 5592735569        1.0          2.0   0.5  0.833333

# %%
overdue_rate_df.isnull().sum()
# Out:
# bad_count      0
# total_count    0
# rate           0
# woe            0
# dtype: int64

# %%
overdue_rate_df.fillna(0,inplace=True)

# %%
overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')

# %%
# overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')，报错：ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object')

new_df = pd.DataFrame({'bad_count': overdue_rate_df['bad_count'],
                       'total_count': overdue_rate_df['total_count'],
                       'rate': overdue_rate_df['rate'],
                       'woe': overdue_rate_df['woe']})
new_df.to_parquet(f'callog_overdue_rate_{month}.parquet', compression='zstd')
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[21], line 7
#       1 # overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')，报错：ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object')
#       3 new_df = pd.DataFrame({'bad_count': overdue_rate_df['bad_count'],
#       4                        'total_count': overdue_rate_df['total_count'],
#       5                        'rate': overdue_rate_df['rate'],
#       6                        'woe': overdue_rate_df['woe']})
# ----> 7 new_df.to_parquet(f'callog_overdue_rate_{month}.parquet', compression='zstd')
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/io/parquet.py:190, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     187 if index is not None:
#     188     from_pandas_kwargs["preserve_index"] = index
# --> 190 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     192 if df.attrs:
#     193     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/table.pxi:4525, in pyarrow.lib.Table.from_pandas()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:345, in pyarrow.lib.array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/array.pxi:85, in pyarrow.lib._ndarray_to_array()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object')

# %%
overdue_rate_df['woe'].describe()
# Out:
# count    1677.000000
# mean        0.815941
# std         0.831409
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.666667
# max         1.666667
# Name: woe, dtype: float64

# %%
overdue_rate_df.head()
# Out:
#             bad_count  total_count  rate       woe
# 86                2.0          4.0   0.5  0.833333
# 4429800292        3.0          3.0   1.0  1.666667
# 4734540036        1.0          2.0   0.5  0.833333
# 5544380802        1.0          2.0   0.5  0.833333
# 5592735569        1.0          2.0   0.5  0.833333

# %%
process_month_calllog(month)
# Out:
# 2023-07
# ['sms_url/2023-07_AM', 'sms_url/2023-07_YM', 'sms_url/2023-07_M']
# Error: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object'), month: 2023-07

# %%
for month in month_files.keys():
    process_month_calllog(month)
# Out:
# 2023-06
# ['sms_url/2023-06_AM', 'sms_url/2023-06_YM', 'sms_url/2023-06_M']
# Error: ("Expected bytes, got a 'int' object", 'Conversion failed for column None with type object'), month: 2023-06
# 2023-07
# ['sms_url/2023-07_AM', 'sms_url/2023-07_YM', 'sms_url/2023-07_M']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/marshall/mypackage/common_tools.py:138, in batch_load_files_to_df(paths, file_type)
#     137 futures = {executor.submit(load_file_to_df, path, file_type): path for path in paths}
# --> 138 for future in as_completed(futures):
#     139     try:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 for month in month_files.keys():
# ----> 2     process_month_calllog(month)
#
# Cell In[8], line 21, in process_month_calllog(month)
#      19 print(month)
#      20 print(files)
# ---> 21 calllog_data = batch_load_files_to_df(files)
#      22 calllog_data = calllog_data[calllog_data['agr_pd7'] == 1]
#      23 calllog_data = calllog_data[(calllog_data['call_records_url'].notnull()) & (calllog_data['call_records_url'] != '[]')]
#
# File ~/marshall/mypackage/common_tools.py:136, in batch_load_files_to_df(paths, file_type)
#     129 """
#     130 并行批量加载文件
#     131 :param paths: 文件路径列表
#     132 :param file_type: 文件类型, 支持parquet,csv,pickle
#     133 :return: 合并后的dataframe
#     134 """
#     135 dfs = []
# --> 136 with ThreadPoolExecutor() as executor:
#     137     futures = {executor.submit(load_file_to_df, path, file_type): path for path in paths}
#     138     for future in as_completed(futures):
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/miniconda3/envs/myz311/lib/python3.11/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniconda3/envs/myz311/lib/python3.11/threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:

# %%
list('abc') + list('def')
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
files = month_files[month]
print(month)
print(files)
calllog_data = batch_load_files_to_df(files)
calllog_data = calllog_data[calllog_data['agr_pd7'] == 1]
calllog_data = calllog_data[(calllog_data['call_records_url'].notnull()) & (calllog_data['call_records_url'] != '[]')]
month_overdue_rate = calllog_data['def_pd7'].mean()
# pattern 提取becallPhone或者call_log_number
def extract_phone(data):
    if data is None or data == '[]':
        return set()
    entries = json.loads(data)
    return set(
        normalize_phone(entry.get('becallPhone'))[-1]
        for entry in entries
        if 'becallPhone' in entry or 'call_log_number' in entry
    ).union(
        normalize_phone(entry.get('call_log_number'))[-1]
        for entry in entries
        if 'call_log_number' in entry
    )
# 如果becallPhone不存在，就提取call_log_number

calllog_data['calllog'] = calllog_data['call_records_url_data'].apply(extract_phone)
# Out:
# 2024-06
# ['sms_url/2024-06_AM', 'sms_url/2024-06_YM', 'sms_url/2024-06_M']

# %%
calllog_data['calllog'].sample(5)
# Out:
# 991      {, 528016203428, 527950448115, 5521620992, 554...
# 23998    {4432457732, 4435419142, 4434375688, 443174401...
# 1693     {9243951105, 5509154819, 8145302535, 555774976...
# 37051    {2201065985, 5535492867, 7971351819, 220171367...
# 26514    {4344978434, 4438672134, 4341006599, 434128615...
# Name: calllog, dtype: object

# %% [markdown]
# ## check_case_call

# %%
case_check_call = pd.read_parquet('calllog_overdue_rate_2024-03.parquet')

# %%
case_check_call.head()
# Out:
#         phone  bad_count  total_count    rate       woe
# 0  4429800292     2809.0      32426.0  0.0866  0.712457
# 1          86     3678.0      30154.0  0.1220  1.003692
# 2                 2420.0      17894.0  0.1352  1.112288
# 3  3341690119     1960.0      16783.0  0.1168  0.960911
# 4  5512046092     1274.0      15470.0  0.0824  0.677903

# %%
case_check_call.describe()
# Out:
#           bad_count   total_count          rate           woe
# count  1.652206e+06  1.652206e+06  1.652206e+06  1.652206e+06
# mean   1.268689e+00  1.094403e+01  2.634886e-01  2.167716e+00
# std    7.910757e+00  5.686508e+01  4.251789e-01  3.497939e+00
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  4.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.000000e+00  1.000000e+01  5.000000e-01  4.113491e+00
# max    3.678000e+03  3.242600e+04  1.000000e+00  8.226982e+00

# %%
case_check_call['total_count'].quantile(0.99)
# Out:
# 100.0

# %%
case_check_call[case_check_call['total_count'] > case_check_call['total_count'].quantile(0.99)]['woe'].describe()
# Out:
# count    16481.000000
# mean         0.550947
# std          1.306492
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.587406
# max          8.226982
# Name: woe, dtype: float64

# %%
pd.cut(case_check_call[case_check_call['total_count'] > 100]['woe'], bins=20).value_counts().sort_index()
# Out:
# woe
# (-0.00823, 0.411]    11560
# (0.411, 0.823]        1837
# (0.823, 1.234]        1305
# (1.234, 1.645]         605
# (1.645, 2.057]         224
# (2.057, 2.468]         114
# (2.468, 2.879]          67
# (2.879, 3.291]          33
# (3.291, 3.702]          42
# (3.702, 4.113]          30
# (4.113, 4.525]          21
# (4.525, 4.936]          10
# (4.936, 5.348]          11
# (5.348, 5.759]           8
# (5.759, 6.17]          108
# (6.17, 6.582]          426
# (6.582, 6.993]          11
# (6.993, 7.404]           7
# (7.404, 7.816]           3
# (7.816, 8.227]          59
# Name: count, dtype: int64

# %%
calllog_data['call_records_url_data'][0]

# %%
overdue_rate_df.shape
# Out:
# (753, 4)

# %%
overdue_rate_df.head(50)
# Out:
#      bad_count  total_count    rate       woe
#    140570012.0  358673722.0  0.3919  0.935081
# l   43818216.0  109943373.0  0.3986  0.951067
# a   30738172.0   76884488.0  0.3998  0.953931
# e   23558191.0   61365372.0  0.3839  0.915993
# c   22720694.0   56901435.0  0.3993  0.952738
# 1   14817549.0   39629738.0  0.3739  0.892133
# t   15665635.0   38636940.0  0.4055  0.967531
# o   13254040.0   30520903.0  0.4343  1.036248
# 2   11100916.0   30186558.0  0.3677  0.877339
# 5   10392366.0   26687675.0  0.3894  0.929116
# 7    9785615.0   25768006.0  0.3798  0.906210
# n   11037550.0   25090836.0  0.4399  1.049610
# 6    9132123.0   23119680.0  0.3950  0.942478
# i    9466005.0   22299790.0  0.4245  1.012865
# 3    8463732.0   21803520.0  0.3882  0.926253
# 9    8774707.0   20983458.0  0.4182  0.997833
# 4    7445600.0   20752063.0  0.3588  0.856104
# b    7411112.0   19379428.0  0.3824  0.912414
# 8    7356857.0   18810901.0  0.3911  0.933172
# p    6017396.0   16705049.0  0.3602  0.859444
# m    6866462.0   16698497.0  0.4112  0.981131
# d    6519213.0   15645165.0  0.4167  0.994254
# r    6332690.0   14031931.0  0.4513  1.076811
# s    5124367.0   11248525.0  0.4556  1.087070
# g    4782151.0   10203329.0  0.4687  1.118327
# u    4135239.0    8976488.0  0.4607  1.099239
# h    3208820.0    8840775.0  0.3630  0.866125
# y    3085906.0    8490638.0  0.3634  0.867079
# w     788365.0    1624557.0  0.4853  1.157935
# v     313346.0     914664.0  0.3426  0.817450
# x     440054.0     905109.0  0.4862  1.160083
# j     314787.0     857877.0  0.3669  0.875431
# z     256126.0     750567.0  0.3412  0.814110
# é     255463.0     523428.0  0.4881  1.164616
# f     190044.0     506271.0  0.3754  0.895712
# k     113874.0     326642.0  0.3486  0.831766
# á      88880.0     249298.0  0.3565  0.850616
# ñ      63675.0     159960.0  0.3981  0.949874
# q      59983.0     146781.0  0.4087  0.975166
# í      57480.0     140237.0  0.4099  0.978029
# ó      40386.0     104964.0  0.3848  0.918140
# ú      12206.0      33084.0  0.3689  0.880203
# ü       1536.0       3899.0  0.3939  0.939853
# ي        528.0       1123.0  0.4702  1.121906
# ب        516.0        953.0  0.5414  1.291791
# 𝓪        207.0        721.0  0.2871  0.685026
# ᴀ        569.0        670.0  0.8493  2.026446
# 𝓃         29.0        662.0  0.0438  0.104508
# ə        635.0        637.0  0.9969  2.378623
# 𝓁         29.0        600.0  0.0483  0.115245

# %%
for phones, label in zip(calllog_data['call_records_url_data'], calllog_data['def_pd7']):
    if phones is None:
        continue
    for phone in phones:
        phone = normalize_phone(phone)[-1]
        if phone not in calllog_overdue_rate:
            calllog_overdue_rate[phone] = [0, 0, 0]
        if label == 1:
            calllog_overdue_rate[phone][0] += 1
        calllog_overdue_rate[phone][1] += 1
        calllog_overdue_rate[phone][2] = round(calllog_overdue_rate[phone][0] / calllog_overdue_rate[phone][1], 4)
overdue_rate_df = pd.DataFrame(calllog_overdue_rate).T
overdue_rate_df.rename(columns={0: 'bad_count', 1: 'total_count', 2: 'rate'}, inplace=True)
overdue_rate_df.sort_values('total_count', ascending=False, inplace=True)
overdue_rate_df['woe'] = overdue_rate_df['rate'].apply(lambda x: x / month_overdue_rate)
overdue_rate_df.to_parquet(f'callog_overdue_rate_{month}.parquet',compression='zstd')
print(f"Finish processing {month}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for phones, label in zip(calllog_data['call_records_url_data'], calllog_data['def_pd7']):
#       2     if phones is None:
#       3         continue
#
# NameError: name 'calllog_data' is not defined

# %% [markdown]
# # 滑动窗口特征

# %%
## todo 定期把配置文件算好，ssh发送到固定路径

# %%
# 平滑后的woe 分n箱后+套路 5=< n <= 10

# %%
# 通话时长+频次

# %%
# 南美其他国家只看Y

# %%
# 按模块做

# %%
def generate_month_badcount(file_path=None, month=None):
    """
    生成某个月app逾期率文件
    :param file_path: 生成配置文件的文件路径
    :param month: 月份,'YYYY-MM'
    :param applist_data: 如果applist_data不为空，则直接使用applist_data
    :return: 
    """
    file_names = os.listdir(file_path)
    month_files = defaultdict(list)
    for file_name in file_names:
        file_name = file_path / file_name   
        match = re.search(r'(\d{4}-\d{2})',str(file_name))
        if match and match.group() == month: 
            month_files[month].append(str(file_name))
    files = month_files[month]
    print(files)
    data = batch_load_files_to_df(files)
    data = data[['def_pd7','agr_pd7']]
    data['bad'] = np.where(data['agr_pd7'] == 1, data['def_pd7'], None)
    data = data[data['bad'].notnull()]
    total_count = data['def_pd7'].count()
    bad_count = data['def_pd7'].sum()
    return month, total_count, bad_count

# %%
tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')
month_badcount = pd.DataFrame()
months = ['2023-06','2023-07','2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']
task_list = [(raw_dir,month) for month in months]
for month in months:
    month, total_count, bad_count = generate_month_badcount(raw_dir, month)
    month_badcount = pd.concat([month_badcount, pd.DataFrame({'month': [month], 'total_count': [total_count], 'bad_count': [bad_count]})], axis=0)
# Out:
# ['/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-06-30.pqt']
# ['/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-07-31.pqt']
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-08-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-27.pqt']
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-09-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-09-26.pqt']
# ['/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-10-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-10-31.pqt']
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-11-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-11-27.pqt', '/home/longxiaolei/raw_m ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2023-12-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2023-12-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2023-12-21.pqt', '/home/longxiaolei ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-01-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-01-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-01-20.pqt', '/home/longxiaole ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-02-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-02-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-02-23.pqt', '/home/longxiaolei/r ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-03-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-03-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-03-20.pqt', '/home/longxiaole ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-04-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-04-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-04-21.pqt', '/home/longxiaolei ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-05-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-05-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-05-20.pqt', '/home/longxiaol ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-06-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-06-21.pqt', '/home/longxiaolei ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-24.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-25.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-30.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-21.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-22.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-23.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-26.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-27.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-28.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-29.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-07-31.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-20.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-07-21.pqt', '/home/longxiaolei ...
# ['/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-02.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-03.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-04.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-07.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-08.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-09.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-12.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-13.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-14.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-15.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-17.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-18.pqt', '/home/longxiaolei/raw_mx/newcust/raw_M_2024-08-19.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-01.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-06.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-11.pqt', '/home/longxiaolei/raw_mx/newcust/raw_AM_2024-08-16.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-05.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-10.pqt', '/home/longxiaolei/raw_mx/newcust/raw_YM_2024-08-16.pqt']

# %%
month_badcount.to_parquet(tmp_dir / 'month_badcount.parquet',compression='zstd')

# %%
def generate_app_config_data(
        calc_month:str,
        rlevel_bins:int, 
        window_size:int
):
    """
    生成配置数据，前三个月的数据
    :param calc_month:  计算月份
    :param rlevel_bins:  分箱数
    :param window_size: 滑动窗口大小
    :return:
    """
    now_month = datetime.strptime(calc_month, '%Y-%m')
    config_all = pd.DataFrame()
    # 遍历当前文件夹下的所有文件
    for file in os.listdir(tmp_dir):
        if file.startswith('app_overdue_rate'):
            config_month = datetime.strptime(file.split('_')[-1].split('.')[0], '%Y-%m')
            month_diff = (now_month.year - config_month.year) * 12 + now_month.month - config_month.month
            if 1 < month_diff <= window_size+1:
                config = pd.read_parquet(file)
                mask = (config['total_count'] > 50)     # 滑动窗口中的每个月的app的总数大于50
                config = config[mask]
                config_all = pd.concat([config_all, config], axis=0)
        else:
            continue
    if config_all.empty:
        print(f'config_all is empty, month: {calc_month}')
        return 
        # config_all = config_all[config_all.groupby('app')['total_count'].transform('count') == num_of_configs]  # 选取在每个月都出现的app
    config_all = config_all[config_all.groupby('app')['bad_rate'].transform('std') < config_all.groupby('app')['bad_rate'].transform('std').quantile(0.85)] # 去除overdue_rate的标准差大于0.9分位数的app
    if config_all.empty:
        return
    config_all = config_all.groupby('app').agg({'bad_count': 'sum', 'total_count': 'sum'}).reset_index()
    config_all['bad_rate'] = config_all['bad_count'] / config_all['total_count']
    config_all = config_all.copy()
    now_month = month_badcount[month_badcount['month'] == calc_month]
    bad_rate_total = now_month['bad_count'] / now_month['total_count']
    bad_rate_total = bad_rate_total.values[0]
  
    config_all['woe'] = np.where(
        (config_all['bad_rate'] == 0) | (config_all['bad_rate'] == 1),
        0,
        np.log( (config_all['bad_rate'] / bad_rate_total / 
                ((1 - config_all['bad_rate']) / (1 - bad_rate_total)))
                )
    )
    config_all['woe_bin_freq'] = pd.qcut(config_all['woe'], rlevel_bins, duplicates='drop')
    config_all['level_freq'] = config_all['woe_bin_freq'].cat.codes+1
    config_all['woe_bin_dist'] = pd.cut(config_all['woe'], rlevel_bins, duplicates='drop')
    config_all['level_dist'] = config_all['woe_bin_dist'].cat.codes+1
    config_all['woe_bin_freq'] = config_all['woe_bin_freq'].astype(str)
    config_all['woe_bin_dist'] = config_all['woe_bin_dist'].astype(str)
    print('freq', config_all['level_freq'].value_counts())
    print('dist', config_all['level_dist'].value_counts())
    return config_all


def generate_sender_config_data(
        calc_month:str,
        rlevel_bins:int, 
        window_size:int
):
    """
    生成配置数据，前三个月的数据
    :param calc_month:  计算月份
    :param rlevel_bins:  分箱数
    :param window_size: 滑动窗口大小
    :return:
    """
    now_month = datetime.strptime(calc_month, '%Y-%m')
    config_all = pd.DataFrame()
    for file in os.listdir(tmp_dir):
        if file.startswith('sender_overdue_rate'):
            config_month = datetime.strptime(file.split('_')[-1].split('.')[0], '%Y-%m')
            month_diff = (now_month.year - config_month.year) * 12 + now_month.month - config_month.month
            if 1 < month_diff <= window_size+1:
                config = pd.read_parquet(file)
                mask = (config['total_count'] > 50) 
                config = config[mask]
                config_all = pd.concat([config_all, config], axis=0)
        else:
            continue
    if config_all.empty:
        print(f'config_all is empty, month: {calc_month}')
        return
                
                
    config_all = config_all[config_all.groupby('sender')['bad_rate'].transform('std') < config_all.groupby('sender')['bad_rate'].transform('std').quantile(0.85)]
    if config_all.empty:
        return 
    config_all = config_all.groupby('sender').agg({'bad_count': 'sum', 'total_count': 'sum'}).reset_index()
    config_all['bad_rate'] = config_all['bad_count'] / config_all['total_count']
    config_all = config_all.copy()
    now_month = month_badcount[month_badcount['month'] == calc_month]
    bad_rate_total = now_month['bad_count'] / now_month['total_count']
    bad_rate_total = bad_rate_total.values[0]
    
    config_all['woe'] = np.where(
        (config_all['bad_rate'] == 0) | (config_all['bad_rate'] == 1),
        0,
        np.log( (config_all['bad_rate'] / bad_rate_total) / 
                ((1 - config_all['bad_rate']) / (1 - bad_rate_total)))
    )
    config_all['woe_bin_dist'] = pd.cut(config_all['woe'], rlevel_bins, duplicates='drop')
    # 选出占比超过40%的woe_bin_dist，再将其等频分10箱，每箱随机选百分之10的数据
    woe_bin_dist = config_all['woe_bin_dist'].value_counts(normalize=True)
    woe_bin_dist = woe_bin_dist[woe_bin_dist > 0.4]
    woe_bin_dist_index = woe_bin_dist.index
    woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)]
    woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
    # 每箱随机选百分之10的数据
    woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
    retain_index = woe_bin_dist.index.get_level_values(1)
    # 将config_all的占比超过40%的数据用woe_bin_dist替换
    print(woe_bin_dist.head())
    print(config_all.head())
    config_all = pd.concat([config_all[~config_all['woe_bin_dist'].isin(woe_bin_dist_index)], config_all[config_all.index.isin(retain_index)]],  axis=0)
    
    config_all['level_dist'] = config_all['woe_bin_dist'].cat.codes+1
    
    config_all['woe_bin_freq'] = pd.qcut(config_all['woe'], rlevel_bins, duplicates='drop')
    config_all['level_freq'] = config_all['woe_bin_freq'].cat.codes+1
    
    config_all['woe_bin_freq'] = config_all['woe_bin_freq'].astype(str)
    config_all['woe_bin_dist'] = config_all['woe_bin_dist'].astype(str)
    print(config_all.dtypes)
    config_all = config_all[['sender','bad_count','total_count','bad_rate','woe','level_freq','level_dist']]
    print('freq', config_all['level_freq'].value_counts())
    print('dist', config_all['level_dist'].value_counts())
    return config_all

def generate_word_config_data(
        calc_month:str,
        rlevel_bins:int, 
        window_size:int
):
    """
    生成配置数据，前三个月的数据
    :param calc_month:  计算月份
    :param rlevel_bins:  分箱数
    :param window_size: 滑动窗口大小
    :return:
    """

    now_month = datetime.strptime(calc_month, '%Y-%m')
    config_all = pd.DataFrame()
    for file in os.listdir(tmp_dir):
        if file.startswith('word_overdue_rate'):
            config_month = datetime.strptime(file.split('_')[-1].split('.')[0], '%Y-%m')
            month_diff = (now_month.year - config_month.year) * 12 + now_month.month - config_month.month
            if 1 < month_diff <= window_size+1:
                config = pd.read_parquet(file)
                mask = (config['total_count'] > 100) 
                config = config[mask]
                config_all = pd.concat([config_all, config], axis=0)
        else:
            continue
    if config_all.empty:
        print(f'config_all is empty, month: {calc_month}')
        return
    
    config_all = config_all[config_all.groupby('word')['bad_rate'].transform('std') < config_all.groupby('word')['bad_rate'].transform('std').quantile(0.85)]
    if config_all.empty:
        return 
    config_all = config_all.groupby('word').agg({'bad_count': 'sum', 'total_count': 'sum'}).reset_index()
    config_all['bad_rate'] = config_all['bad_count'] / config_all['total_count']
    config_all = config_all.copy()
    
    now_month = month_badcount[month_badcount['month'] == calc_month]
    bad_rate_total = now_month['bad_count'] / now_month['total_count']
    bad_rate_total = bad_rate_total.values[0]
    
    config_all['woe'] = np.where(
        (config_all['bad_rate'] == 0) | (config_all['bad_rate'] == 1),
        0,
        np.log( (config_all['bad_rate'] / bad_rate_total) / 
                ((1 - config_all['bad_rate']) / (1 - bad_rate_total)))
    )
    
    config_all['woe_bin_freq'] = pd.qcut(config_all['woe'], rlevel_bins, duplicates='drop')
    config_all['level_freq'] = config_all['woe_bin_freq'].cat.codes+1
    config_all['woe_bin_dist'] = pd.cut(config_all['woe'], rlevel_bins, duplicates='drop')
    config_all['level_dist'] = config_all['woe_bin_dist'].cat.codes+1
    config_all['woe_bin_freq'] = config_all['woe_bin_freq'].astype(str)
    config_all['woe_bin_dist'] = config_all['woe_bin_dist'].astype(str)
    print('freq', config_all['level_freq'].value_counts())
    print('dist', config_all['level_dist'].value_counts())
    return config_all

# %%
tmp_dir = Path('/home/mayongzhi/marshall/sender_word_call_app/tmp_config')

# %%
word_config_dir = work_dir / 'word_config_window'
if not word_config_dir.exists():
    word_config_dir.mkdir(exist_ok=True)
app_config_dir = work_dir / 'app_config_window'
if not app_config_dir.exists():
    app_config_dir.mkdir(exist_ok=True)
sender_config_dir = work_dir / 'sender_config_window'
if not sender_config_dir.exists():
    sender_config_dir.mkdir(exist_ok=True)

# %%
for month in ['2023-06','2023-07','2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
    print('=' * 20, month, '=' * 20)
    print('sender')
    overdue_rate_df = generate_sender_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    if overdue_rate_df is None:
        continue
    print(overdue_rate_df['level_dist'].value_counts())
    
    overdue_rate_df.to_parquet(sender_config_dir / f'sender_overdue_rate_window3_{month}.parquet',compression='zstd')
# Out:
# ==================== 2023-06 ====================
# sender
# config_all is empty, month: 2023-06
# ==================== 2023-07 ====================
# sender
# config_all is empty, month: 2023-07
# ==================== 2023-08 ====================
# sender
# ==================== 2023-09 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                           sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.452, 0.624] 7649  5593383815         78          157  0.496815  0.500339
#                 30    2201711391         54          123  0.439024  0.267956
#                 8108  5594180566         85          169  0.502959  0.524913
#                 7944  5594180332         76          176  0.431818  0.238641
#                 6575  5592738824         72          161  0.447205  0.301108
#
#                          woe_bin_dist
# woe_bin_dist
# (-0.452, 0.624] 7649  (-0.452, 0.624]
#                 30    (-0.452, 0.624]
#                 8108  (-0.452, 0.624]
#                 7944  (-0.452, 0.624]
#                 6575  (-0.452, 0.624]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0  10080       2056         3638  0.565146  0.775151     (0.624, 1.7]
# 1  10086      39000        73182  0.532918  0.644941     (0.624, 1.7]
# 2  10090      46826        93969  0.498313  0.506331  (-0.452, 0.624]
# 3   1010        201          362  0.555249  0.734979     (0.624, 1.7]
# 4   1020      12700        24638  0.515464  0.574954  (-0.452, 0.624]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 3     202
# 9     201
# 7     201
# 10    201
# 8     201
# 1     201
# 6     201
# 2     201
# 5     201
# 4     200
# Name: count, dtype: int64
# dist level_dist
# 6     1146
# 7      806
# 5       44
# 8        6
# 3        2
# 4        2
# 9        2
# 1        1
# 10       1
# Name: count, dtype: int64
# level_dist
# 6     1146
# 7      806
# 5       44
# 8        6
# 3        2
# 4        2
# 9        2
# 1        1
# 10       1
# Name: count, dtype: int64
# ==================== 2023-10 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                           sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.61, 0.489] 5938   4141880493         92          224  0.410714  0.107300
#                8477   4427322631         71          150  0.473333  0.361545
#                20127  8141738606         92          207  0.444444  0.245169
#                15626  5594193280         92          221  0.416290  0.130289
#                1722   3341604489        140          326  0.429448  0.184209
#
#                         woe_bin_dist
# woe_bin_dist
# (-0.61, 0.489] 5938   (-0.61, 0.489]
#                8477   (-0.61, 0.489]
#                20127  (-0.61, 0.489]
#                15626  (-0.61, 0.489]
#                1722   (-0.61, 0.489]
#   sender  bad_count  total_count  bad_rate       woe    woe_bin_dist
# 0  10080       2762         5371  0.514243  0.525301  (0.489, 1.588]
# 1  10086      52555       103873  0.505954  0.492132  (0.489, 1.588]
# 2  10090      71997       146400  0.491783  0.435441  (-0.61, 0.489]
# 3   1010        406          657  0.617960  0.949213  (0.489, 1.588]
# 4   1020      18939        38205  0.495720  0.451194  (-0.61, 0.489]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 9     328
# 1     326
# 4     323
# 7     323
# 5     323
# 8     322
# 6     322
# 3     322
# 2     320
# 10    318
# Name: count, dtype: int64
# dist level_dist
# 6     2003
# 7     1185
# 5       19
# 8        6
# 3        4
# 10       4
# 4        3
# 1        2
# 9        1
# Name: count, dtype: int64
# level_dist
# 6     2003
# 7     1185
# 5       19
# 8        6
# 3        4
# 10       4
# 4        3
# 1        2
# 9        1
# Name: count, dtype: int64
# ==================== 2023-11 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                            sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.325, 0.747] 2393   3341593131         97          200  0.485000  0.328456
#                 19529  8141630674         72          184  0.391304 -0.053359
#                 18357  8141599215        198          496  0.399194 -0.020353
#                 12825  5593023849         41          111  0.369369 -0.146450
#                 8850   4429254452         85          178  0.477528  0.298525
#
#                           woe_bin_dist
# woe_bin_dist
# (-0.325, 0.747] 2393   (-0.325, 0.747]
#                 19529  (-0.325, 0.747]
#                 18357  (-0.325, 0.747]
#                 12825  (-0.325, 0.747]
#                 8850   (-0.325, 0.747]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0  10080       2639         5410  0.487800  0.339665  (-0.325, 0.747]
# 1  10086      52832       111055  0.475728  0.291310  (-0.325, 0.747]
# 2  10090      69952       139260  0.502312  0.397723  (-0.325, 0.747]
# 3   1020      17632        37204  0.473928  0.284089  (-0.325, 0.747]
# 4    110      61010       125668  0.485486  0.330400  (-0.325, 0.747]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 5     387
# 3     386
# 10    385
# 1     385
# 6     385
# 2     385
# 8     385
# 9     385
# 4     383
# 7     382
# Name: count, dtype: int64
# dist level_dist
# 6     2416
# 5     1370
# 7       33
# 3        9
# 4        8
# 10       4
# 8        3
# 1        2
# 2        2
# 9        1
# Name: count, dtype: int64
# level_dist
# 6     2416
# 5     1370
# 7       33
# 3        9
# 4        8
# 10       4
# 8        3
# 1        2
# 2        2
# 9        1
# Name: count, dtype: int64
# ==================== 2023-12 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                            sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.651, 0.492] 17891  5595062552        103          219  0.470320  0.170793
#                 1908   3341591324         85          231  0.367965 -0.251301
#                 9303   4951460087         49          139  0.352518 -0.318335
#                 16403  5594183665        101          278  0.363309 -0.271375
#                 3904   3341602109         48          152  0.315789 -0.483535
#
#                           woe_bin_dist
# woe_bin_dist
# (-0.651, 0.492] 17891  (-0.651, 0.492]
#                 1908   (-0.651, 0.492]
#                 9303   (-0.651, 0.492]
#                 16403  (-0.651, 0.492]
#                 3904   (-0.651, 0.492]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0  10080       2058         4865  0.423022 -0.020727  (-0.651, 0.492]
# 1  10086      40643        93610  0.434174  0.024812  (-0.651, 0.492]
# 2  10090      53171       122749  0.433168  0.020719  (-0.651, 0.492]
# 3   1020      13462        33610  0.400536 -0.113580  (-0.651, 0.492]
# 4    110      45539       108468  0.419838 -0.033783  (-0.651, 0.492]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 4     381
# 1     367
# 6     364
# 8     364
# 9     364
# 10    363
# 3     363
# 7     362
# 2     361
# 5     347
# Name: count, dtype: int64
# dist level_dist
# 5     2796
# 4      793
# 3       21
# 6       15
# 2        5
# 1        3
# 9        2
# 10       1
# Name: count, dtype: int64
# level_dist
# 5     2796
# 4      793
# 3       21
# 6       15
# 2        5
# 1        3
# 9        2
# 10       1
# Name: count, dtype: int64
# ==================== 2024-01 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                              sender  bad_count  total_count  bad_rate  \
# woe_bin_dist
# (-1.078, -0.0178] 14678  5592738799         43          155  0.277419
#                   13867  5592283932        104          289  0.359862
#                   27776  8141596845         61          172  0.354651
#                   34730  8673001933         80          224  0.357143
#                   5699   3341713598         47          129  0.364341
#
#                               woe       woe_bin_dist
# woe_bin_dist
# (-1.078, -0.0178] 14678 -0.525670  (-1.078, -0.0178]
#                   13867 -0.144336  (-1.078, -0.0178]
#                   27776 -0.167028  (-1.078, -0.0178]
#                   34730 -0.156158  (-1.078, -0.0178]
#                   5699  -0.124943  (-1.078, -0.0178]
#   sender  bad_count  total_count  bad_rate       woe       woe_bin_dist
# 0  10080       1868         4575  0.408306  0.060656   (-0.0178, 1.043]
# 1  10086      40678        99290  0.409689  0.066377   (-0.0178, 1.043]
# 2  10090      40667       104258  0.390061 -0.015426   (-0.0178, 1.043]
# 3   1010        276          669  0.412556  0.078220   (-0.0178, 1.043]
# 4   1020      11131        29729  0.374416 -0.081691  (-1.078, -0.0178]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 1     938
# 6     935
# 3     934
# 8     933
# 9     933
# 4     932
# 10    932
# 5     932
# 7     929
# 2     927
# Name: count, dtype: int64
# dist level_dist
# 5     6300
# 4     2974
# 3       25
# 2       15
# 1        6
# 6        2
# 9        1
# 7        1
# 10       1
# Name: count, dtype: int64
# level_dist
# 5     6300
# 4     2974
# 3       25
# 2       15
# 1        6
# 6        2
# 9        1
# 7        1
# 10       1
# Name: count, dtype: int64
# ==================== 2024-02 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                            sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.206, 0.685] 23044  8121865534         66          152  0.434211  0.171512
#                 23745  8141595513         89          246  0.361789 -0.131405
#                 22998  7821966399        414          414  1.000000  0.000000
#                 30875  8159805393         81          220  0.368182 -0.103820
#                 11875  5592739613         73          192  0.380208 -0.052459
#
#                           woe_bin_dist
# woe_bin_dist
# (-0.206, 0.685] 23044  (-0.206, 0.685]
#                 23745  (-0.206, 0.685]
#                 22998  (-0.206, 0.685]
#                 30875  (-0.206, 0.685]
#                 11875  (-0.206, 0.685]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0  10080       2235         5261  0.424824  0.133204  (-0.206, 0.685]
# 1  10086      41635        96881  0.429754  0.153350  (-0.206, 0.685]
# 2  10090      39190       106638  0.367505 -0.106730  (-0.206, 0.685]
# 3   1010        282          643  0.438569  0.189234  (-0.206, 0.685]
# 4   1020      11584        30823  0.375823 -0.071110  (-0.206, 0.685]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 8     1610
# 1     1595
# 3     1595
# 7     1591
# 10    1588
# 5     1587
# 6     1587
# 2     1580
# 4     1579
# 9     1560
# Name: count, dtype: int64
# dist level_dist
# 5     13683
# 6      2084
# 7        32
# 4        31
# 10       12
# 2        10
# 3         9
# 9         6
# 8         3
# 1         2
# Name: count, dtype: int64
# level_dist
# 5     13683
# 6      2084
# 7        32
# 4        31
# 10       12
# 2        10
# 3         9
# 9         6
# 8         3
# 1         2
# Name: count, dtype: int64
# ==================== 2024-03 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                           sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.61, 0.607] 26615  8141657401         65          174  0.373563  0.047525
#                19680  5595491373         46          158  0.291139 -0.325372
#                20967  5595493064         61          208  0.293269 -0.315073
#                14317  5594522981        213          710  0.300000 -0.282812
#                13407  5594522060        259          751  0.344874 -0.077165
#
#                         woe_bin_dist
# woe_bin_dist
# (-0.61, 0.607] 26615  (-0.61, 0.607]
#                19680  (-0.61, 0.607]
#                20967  (-0.61, 0.607]
#                14317  (-0.61, 0.607]
#                13407  (-0.61, 0.607]
#   sender  bad_count  total_count  bad_rate       woe    woe_bin_dist
# 0  10080       2254         5349  0.421387  0.247404  (-0.61, 0.607]
# 1  10086      42103       101613  0.414347  0.218461  (-0.61, 0.607]
# 2  10090      35409       105816  0.334628 -0.122841  (-0.61, 0.607]
# 3   1020      11054        29188  0.378717  0.069490  (-0.61, 0.607]
# 4    110      49802       114157  0.436259  0.308126  (-0.61, 0.607]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 1     384
# 8     384
# 6     384
# 10    383
# 3     383
# 5     383
# 4     382
# 7     381
# 2     381
# 9     380
# Name: count, dtype: int64
# dist level_dist
# 6     3347
# 5      213
# 7      171
# 8       29
# 9       21
# 10      18
# 4       15
# 3        8
# 1        2
# 2        1
# Name: count, dtype: int64
# level_dist
# 6     3347
# 5      213
# 7      171
# 8       29
# 9       21
# 10      18
# 4       15
# 3        8
# 1        2
# 2        1
# Name: count, dtype: int64
# ==================== 2024-04 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                            sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.772, 0.446] 26061  8159802472         43          151  0.284768 -0.517736
#                 7755   4779650690         84          271  0.309963 -0.397097
#                 24324  8141655919         67          232  0.288793 -0.498058
#                 11573  5594526023         96          299  0.321070 -0.345663
#                 10710  5594522561        106          391  0.271100 -0.585855
#
#                           woe_bin_dist
# woe_bin_dist
# (-0.772, 0.446] 26061  (-0.772, 0.446]
#                 7755   (-0.772, 0.446]
#                 24324  (-0.772, 0.446]
#                 11573  (-0.772, 0.446]
#                 10710  (-0.772, 0.446]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0            611727      1354605  0.451591  0.208949  (-0.772, 0.446]
# 1  10080       2423         5635  0.429991  0.121308  (-0.772, 0.446]
# 2  10086      44107        97185  0.453846  0.218051  (-0.772, 0.446]
# 3  10090      32531        99337  0.327481 -0.316404  (-0.772, 0.446]
# 4   1020       9844        27602  0.356641 -0.186779  (-0.772, 0.446]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 8     374
# 1     356
# 10    356
# 5     356
# 6     355
# 2     355
# 3     355
# 7     355
# 4     355
# 9     336
# Name: count, dtype: int64
# dist level_dist
# 6     2970
# 5      260
# 7      211
# 8       62
# 4       17
# 9       17
# 10       8
# 3        6
# 1        1
# 2        1
# Name: count, dtype: int64
# level_dist
# 6     2970
# 5      260
# 7      211
# 8       62
# 4       17
# 9       17
# 10       8
# 3        6
# 1        1
# 2        1
# Name: count, dtype: int64
# ==================== 2024-05 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                             sender  bad_count  total_count  bad_rate  \
# woe_bin_dist
# (-1.023, -0.153] 13386  5595494070         83          274  0.302920
#                  19253  8141638144         68          218  0.311927
#                  21934  8141656050         68          242  0.280992
#                  5446   5541728857         37          108  0.342593
#                  5922   5592627269         41          127  0.322835
#
#                              woe      woe_bin_dist
# woe_bin_dist
# (-1.023, -0.153] 13386 -0.606958  (-1.023, -0.153]
#                  19253 -0.564653  (-1.023, -0.153]
#                  21934 -0.713073  (-1.023, -0.153]
#                  5446  -0.425287  (-1.023, -0.153]
#                  5922  -0.514301  (-1.023, -0.153]
#   sender  bad_count  total_count  bad_rate       woe      woe_bin_dist
# 0            838714      1816778  0.461649  0.072769   (-0.153, 0.717]
# 1  10080       1967         4967  0.396014 -0.195628  (-1.023, -0.153]
# 2  10086      42779        97734  0.437708 -0.023993   (-0.153, 0.717]
# 3  10090      28911        93222  0.310131 -0.573034  (-1.023, -0.153]
# 4   1020       8203        24669  0.332523 -0.470323  (-1.023, -0.153]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 9     550
# 5     411
# 4     391
# 1     391
# 2     391
# 8     391
# 3     390
# 7     390
# 6     370
# 10    231
# Name: count, dtype: int64
# dist level_dist
# 6     2294
# 7     1171
# 5      413
# 4       11
# 3        7
# 1        5
# 10       2
# 2        2
# 9        1
# Name: count, dtype: int64
# level_dist
# 6     2294
# 7     1171
# 5      413
# 4       11
# 3        7
# 1        5
# 10       2
# 2        2
# 9        1
# Name: count, dtype: int64
# ==================== 2024-06 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                             sender  bad_count  total_count  bad_rate  \
# woe_bin_dist
# (-1.211, -0.318] 1124   3341596015         54          174  0.310345
#                  6728   5594185667         44          158  0.278481
#                  740    3341595508         37          168  0.220238
#                  2075   3341597193         51          179  0.284916
#                  20593  8141655902         44          168  0.261905
#
#                              woe      woe_bin_dist
# woe_bin_dist
# (-1.211, -0.318] 1124  -0.556831  (-1.211, -0.318]
#                  6728  -0.710332  (-1.211, -0.318]
#                  740   -1.022602  (-1.211, -0.318]
#                  2075  -0.678528  (-1.211, -0.318]
#                  20593 -0.794415  (-1.211, -0.318]
#   sender  bad_count  total_count  bad_rate       woe      woe_bin_dist
# 0      1         56          170  0.329412 -0.469170  (-1.211, -0.318]
# 1  10080       1819         4496  0.404582 -0.144733   (-0.318, 0.575]
# 2  10086      39701        88924  0.446460  0.026692   (-0.318, 0.575]
# 3  10090      27970        80169  0.348888 -0.382254  (-1.211, -0.318]
# 4   1010        329          689  0.477504  0.151631   (-0.318, 0.575]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 6     516
# 5     513
# 1     513
# 9     512
# 3     512
# 4     512
# 10    511
# 8     511
# 2     511
# 7     509
# Name: count, dtype: int64
# dist level_dist
# 6     3024
# 5     1985
# 4       85
# 7        8
# 3        6
# 2        4
# 1        4
# 8        2
# 9        1
# 10       1
# Name: count, dtype: int64
# level_dist
# 6     3024
# 5     1985
# 4       85
# 7        8
# 3        6
# 2        4
# 1        4
# 8        2
# 9        1
# 10       1
# Name: count, dtype: int64
# ==================== 2024-07 ====================
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
#                             sender  bad_count  total_count  bad_rate  \
# woe_bin_dist
# (-1.447, -0.484] 15042  8141636296         52          207  0.251208
#                  1059   3341595777         52          175  0.297143
#                  10626  5595589148         46          150  0.306667
#                  6634   5594186671         47          161  0.291925
#                  2139   3341597081         94          299  0.314381
#
#                              woe      woe_bin_dist
# woe_bin_dist
# (-1.447, -0.484] 15042 -0.856006  (-1.447, -0.484]
#                  1059  -0.624765  (-1.447, -0.484]
#                  10626 -0.579574  (-1.447, -0.484]
#                  6634  -0.649875  (-1.447, -0.484]
#                  2139  -0.543539  (-1.447, -0.484]
#   sender  bad_count  total_count  bad_rate       woe    woe_bin_dist
# 0      1        145          362  0.400552 -0.166988  (-0.484, 0.48]
# 1  10080       2500         5705  0.438212 -0.012246  (-0.484, 0.48]
# 2  10086      45941       103249  0.444953  0.015094  (-0.484, 0.48]
# 3  10090      35379        93449  0.378592 -0.259355  (-0.484, 0.48]
# 4   1010        370          840  0.440476 -0.003054  (-0.484, 0.48]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 1     202
# 10    202
# 5     202
# 6     202
# 9     201
# 8     201
# 3     201
# 2     201
# 4     201
# 7     200
# Name: count, dtype: int64
# dist level_dist
# 5     1128
# 4      814
# 8       22
# 3       18
# 6       16
# 1        6
# 2        4
# 7        3
# 9        1
# 10       1
# Name: count, dtype: int64
# level_dist
# 5     1128
# 4      814
# 8       22
# 3       18
# 6       16
# 1        6
# 2        4
# 7        3
# 9        1
# 10       1
# Name: count, dtype: int64
# ==================== 2024-08 ====================
# sender
#                            sender  bad_count  total_count  bad_rate       woe  \
# woe_bin_dist
# (-0.719, 0.558] 12303  5931200046        415         1018  0.407662 -0.083138
#                 9966   5595500359        131          303  0.432343  0.018204
#                 14438  7474996604          0          485  0.000000  0.000000
#                 2920   3341672481         65          200  0.325000 -0.440387
#                 9139   5594538858        117          344  0.340116 -0.372275
#
#                           woe_bin_dist
# woe_bin_dist
# (-0.719, 0.558] 12303  (-0.719, 0.558]
#                 9966   (-0.719, 0.558]
#                 14438  (-0.719, 0.558]
#                 2920   (-0.719, 0.558]
#                 9139   (-0.719, 0.558]
#   sender  bad_count  total_count  bad_rate       woe     woe_bin_dist
# 0      1        231          511  0.452055  0.098129  (-0.719, 0.558]
# 1  10080       3885         8688  0.447169  0.078383  (-0.719, 0.558]
# 2  10086      73781       163585  0.451025  0.093972  (-0.719, 0.558]
# 3  10090      55507       135356  0.410082 -0.073128  (-0.719, 0.558]
# 4   1020      14982        36625  0.409065 -0.077332  (-0.719, 0.558]
# sender           object
# bad_count         int64
# total_count       int64
# bad_rate        float64
# woe             float64
# woe_bin_dist     object
# level_dist         int8
# woe_bin_freq     object
# level_freq         int8
# dtype: object
# freq level_freq
# 5     268
# 1     263
# 8     263
# 3     263
# 10    263
# 2     262
# 9     262
# 4     262
# 7     262
# 6     257
# Name: count, dtype: int64
# dist level_dist
# 5     2022
# 4      532
# 6       39
# 3       14
# 7        6
# 1        5
# 2        4
# 10       2
# 9        1
# Name: count, dtype: int64
# level_dist
# 5     2022
# 4      532
# 6       39
# 3       14
# 7        6
# 1        5
# 2        4
# 10       2
# 9        1
# Name: count, dtype: int64
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_12854/1277150736.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   woe_bin_dist['woe_bin_dist'] = pd.qcut(woe_bin_dist['woe'], rlevel_bins, duplicates='drop')
# /tmp/ipykernel_12854/1277150736.py:113: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))
# /tmp/ipykernel_12854/1277150736.py:113: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   woe_bin_dist = config_all[config_all['woe_bin_dist'].isin(woe_bin_dist_index)].groupby('woe_bin_dist').apply(lambda x: x.sample(frac=0.1))

# %%
for month in ['2023-06','2023-07','2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07','2024-08']:
    print('=' * 20, month, '=' * 20)
    print('word')
    overdue_rate_config = generate_word_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    if overdue_rate_config is None:
        continue
    overdue_rate_config.to_parquet(word_config_dir / f'word_overdue_rate_window3_{month}.parquet',compression='zstd')
    
    print('app') 
    overdue_rate_df = generate_app_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    if overdue_rate_df is None:
        continue
    overdue_rate_df.to_parquet(app_config_dir / f'app_overdue_rate_window3_{month}.parquet',compression='zstd')
    
    print('sender')
    overdue_rate_df = generate_sender_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    if overdue_rate_df is None:
        continue
    overdue_rate_df.to_parquet(sender_config_dir / f'sender_overdue_rate_window3_{month}.parquet',compression='zstd')
# Out:
# ==================== 2023-06 ====================
# word
# config_all is empty, month: 2023-06
# ==================== 2023-07 ====================
# word
# config_all is empty, month: 2023-07
# ==================== 2023-08 ====================
# word
# ==================== 2023-09 ====================
# word
# freq level_freq
# 8     1691
# 10    1690
# 1     1690
# 3     1690
# 7     1689
# 2     1689
# 6     1689
# 5     1689
# 4     1688
# 9     1687
# Name: count, dtype: int64
# dist level_dist
# 4     10087
# 5      3655
# 3      2106
# 6       620
# 2       291
# 7        73
# 1        36
# 8        15
# 9         6
# 10        3
# Name: count, dtype: int64
# app
# freq level_freq
# 3     338
# 8     338
# 1     337
# 5     337
# 2     336
# 9     336
# 10    336
# 7     336
# 6     336
# 4     335
# Name: count, dtype: int64
# dist level_dist
# 7     1370
# 6     1310
# 8      278
# 5      203
# 9       83
# 4       59
# 10      32
# 3       27
# 2        2
# 1        1
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 1     1240
# 6     1240
# 3     1237
# 9     1235
# 8     1233
# 5     1232
# 10    1231
# 4     1229
# 2     1227
# 7     1225
# Name: count, dtype: int64
# dist level_dist
# 6     11465
# 7       806
# 5        44
# 8         6
# 3         2
# 4         2
# 9         2
# 1         1
# 10        1
# Name: count, dtype: int64
# ==================== 2023-10 ====================
# word
# freq level_freq
# 1     1822
# 9     1822
# 7     1822
# 5     1822
# 3     1821
# 10    1821
# 6     1821
# 2     1821
# 4     1821
# 8     1820
# Name: count, dtype: int64
# dist level_dist
# 4     10561
# 5      5456
# 3       978
# 6       933
# 2       177
# 7        85
# 8        11
# 1         6
# 9         4
# 10        2
# Name: count, dtype: int64
# app
# freq level_freq
# 1     372
# 10    372
# 5     371
# 9     371
# 2     371
# 3     371
# 6     371
# 4     371
# 8     371
# 7     371
# Name: count, dtype: int64
# dist level_dist
# 6     1979
# 7      865
# 5      468
# 8      211
# 4       92
# 9       46
# 3       28
# 10      13
# 2        8
# 1        2
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 3     2182
# 2     2168
# 7     2128
# 5     2128
# 9     2126
# 1     2126
# 6     2124
# 10    2124
# 8     2120
# 4     2027
# Name: count, dtype: int64
# dist level_dist
# 6     20029
# 7      1185
# 5        19
# 8         6
# 3         4
# 10        4
# 4         3
# 1         2
# 9         1
# Name: count, dtype: int64
# ==================== 2023-11 ====================
# word
# freq level_freq
# 1     1897
# 3     1896
# 9     1896
# 6     1896
# 8     1896
# 7     1895
# 10    1895
# 4     1895
# 2     1895
# 5     1895
# Name: count, dtype: int64
# dist level_dist
# 5     8595
# 4     8012
# 6     1048
# 3      982
# 7      152
# 2      133
# 8       14
# 1       12
# 9        6
# 10       2
# Name: count, dtype: int64
# app
# freq level_freq
# 9     381
# 1     379
# 7     379
# 4     379
# 3     378
# 8     378
# 5     378
# 2     378
# 6     378
# 10    376
# Name: count, dtype: int64
# dist level_dist
# 6     2057
# 7      924
# 5      395
# 8      212
# 4      105
# 9       36
# 3       31
# 10      18
# 1        3
# 2        3
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 2     2574
# 1     2566
# 6     2566
# 9     2563
# 5     2559
# 8     2559
# 10    2556
# 3     2551
# 4     2550
# 7     2549
# Name: count, dtype: int64
# dist level_dist
# 6     24161
# 5      1370
# 7        33
# 3         9
# 4         8
# 10        4
# 8         3
# 1         2
# 2         2
# 9         1
# Name: count, dtype: int64
# ==================== 2023-12 ====================
# word
# freq level_freq
# 8     1934
# 10    1932
# 4     1932
# 1     1932
# 2     1932
# 6     1932
# 5     1931
# 3     1931
# 7     1931
# 9     1929
# Name: count, dtype: int64
# dist level_dist
# 4     13296
# 5      3400
# 3      1363
# 6       805
# 2       248
# 7       142
# 8        27
# 1        26
# 10        5
# 9         4
# Name: count, dtype: int64
# app
# freq level_freq
# 6     384
# 3     374
# 5     369
# 1     369
# 10    369
# 9     368
# 2     368
# 8     368
# 4     362
# 7     352
# Name: count, dtype: int64
# dist level_dist
# 5     2385
# 6      643
# 4      388
# 7      165
# 3       64
# 2       17
# 8       15
# 9        3
# 1        2
# 10       1
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 9     2892
# 2     2885
# 1     2883
# 5     2881
# 8     2881
# 7     2880
# 4     2880
# 6     2880
# 3     2874
# 10    2867
# Name: count, dtype: int64
# dist level_dist
# 5     27963
# 4       793
# 3        21
# 6        15
# 2         5
# 1         3
# 9         2
# 10        1
# Name: count, dtype: int64
# ==================== 2024-01 ====================
# word
# freq level_freq
# 8     1993
# 10    1993
# 7     1993
# 6     1993
# 5     1993
# 9     1993
# 4     1993
# 1     1993
# 2     1993
# 3     1993
# Name: count, dtype: int64
# dist level_dist
# 4     9743
# 5     7595
# 6     1334
# 3      821
# 7      236
# 2      135
# 8       40
# 1       12
# 9        9
# 10       5
# Name: count, dtype: int64
# app
# freq level_freq
# 3     394
# 9     383
# 8     374
# 5     374
# 1     374
# 2     373
# 6     373
# 7     373
# 10    364
# 4     353
# Name: count, dtype: int64
# dist level_dist
# 5     1677
# 6     1538
# 7      239
# 4      191
# 3       49
# 8       28
# 9       10
# 10       1
# 2        1
# 1        1
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 6     3632
# 3     3623
# 9     3620
# 8     3610
# 2     3609
# 1     3609
# 5     3605
# 4     3599
# 10    3597
# 7     3585
# Name: count, dtype: int64
# dist level_dist
# 4     29738
# 5      6300
# 3        25
# 2        15
# 1         6
# 6         2
# 9         1
# 7         1
# 10        1
# Name: count, dtype: int64
# ==================== 2024-02 ====================
# word
# freq level_freq
# 1     2050
# 6     2049
# 9     2049
# 10    2048
# 5     2048
# 8     2048
# 4     2048
# 3     2048
# 7     2047
# 2     2047
# Name: count, dtype: int64
# dist level_dist
# 4     10505
# 5      8000
# 6       927
# 3       797
# 7       114
# 2       101
# 8        26
# 9         5
# 1         4
# 10        3
# Name: count, dtype: int64
# app
# freq level_freq
# 1     383
# 8     383
# 6     383
# 10    383
# 3     383
# 2     383
# 5     382
# 7     382
# 4     382
# 9     382
# Name: count, dtype: int64
# dist level_dist
# 4     2135
# 5     1176
# 3      260
# 6      159
# 7       44
# 2       33
# 8       10
# 1        5
# 10       2
# 9        2
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 3     3657
# 8     3471
# 1     3465
# 6     3464
# 2     3462
# 5     3461
# 7     3460
# 10    3460
# 9     3456
# 4     3267
# Name: count, dtype: int64
# dist level_dist
# 6     20835
# 5     13683
# 7        32
# 4        31
# 10       12
# 2        10
# 3         9
# 9         6
# 8         3
# 1         2
# Name: count, dtype: int64
# ==================== 2024-03 ====================
# word
# freq level_freq
# 1     2032
# 10    2031
# 6     2031
# 5     2030
# 9     2030
# 8     2030
# 4     2030
# 3     2030
# 7     2029
# 2     2029
# Name: count, dtype: int64
# dist level_dist
# 4     12772
# 3      3465
# 5      3190
# 6       460
# 2       276
# 7        80
# 1        29
# 8        16
# 9         9
# 10        5
# Name: count, dtype: int64
# app
# freq level_freq
# 6     388
# 4     386
# 9     385
# 1     385
# 2     384
# 3     384
# 10    384
# 8     384
# 5     383
# 7     381
# Name: count, dtype: int64
# dist level_dist
# 4     2852
# 5      493
# 3      376
# 6       73
# 2       34
# 7        9
# 10       5
# 1        2
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 1     3398
# 3     3397
# 7     3396
# 10    3395
# 6     3395
# 9     3394
# 8     3393
# 4     3393
# 5     3393
# 2     3392
# Name: count, dtype: int64
# dist level_dist
# 6     33468
# 5       213
# 7       171
# 8        29
# 9        21
# 10       18
# 4        15
# 3         8
# 1         2
# 2         1
# Name: count, dtype: int64
# ==================== 2024-04 ====================
# word
# freq level_freq
# 7     1989
# 5     1986
# 2     1986
# 10    1986
# 4     1986
# 9     1986
# 1     1986
# 6     1985
# 3     1985
# 8     1982
# Name: count, dtype: int64
# dist level_dist
# 5     9141
# 4     8960
# 6      862
# 3      700
# 7       96
# 2       65
# 8       12
# 9        9
# 1        7
# 10       5
# Name: count, dtype: int64
# app
# freq level_freq
# 5     379
# 2     376
# 7     375
# 1     375
# 10    375
# 4     375
# 8     374
# 9     374
# 3     372
# 6     369
# Name: count, dtype: int64
# dist level_dist
# 4     1989
# 3     1292
# 5      178
# 2      168
# 1       74
# 6       30
# 10       6
# 7        4
# 9        3
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 5     3038
# 9     3032
# 4     3031
# 3     3030
# 1     3030
# 2     3029
# 7     3029
# 10    3025
# 8     3023
# 6     3019
# Name: count, dtype: int64
# dist level_dist
# 6     29703
# 5       260
# 7       211
# 8        62
# 9        17
# 4        17
# 10        8
# 3         6
# 1         1
# 2         1
# Name: count, dtype: int64
# ==================== 2024-05 ====================
# word
# freq level_freq
# 6     1920
# 10    1920
# 4     1920
# 1     1920
# 9     1919
# 5     1919
# 8     1919
# 7     1919
# 3     1919
# 2     1919
# Name: count, dtype: int64
# dist level_dist
# 5     8798
# 6     7574
# 7     1260
# 4      972
# 8      276
# 3      209
# 9       61
# 2       26
# 10      12
# 1        6
# Name: count, dtype: int64
# app
# freq level_freq
# 1     353
# 2     353
# 8     353
# 10    353
# 4     353
# 6     353
# 3     352
# 7     352
# 5     352
# 9     352
# Name: count, dtype: int64
# dist level_dist
# 5     2029
# 6      679
# 4      454
# 7      146
# 3      138
# 2       35
# 8       22
# 9       10
# 1        8
# 10       5
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 3     2459
# 1     2458
# 7     2456
# 6     2456
# 4     2455
# 10    2455
# 8     2454
# 5     2453
# 2     2453
# 9     2452
# Name: count, dtype: int64
# dist level_dist
# 6     22939
# 7      1171
# 5       413
# 4        11
# 3         7
# 1         5
# 10        2
# 2         2
# 9         1
# Name: count, dtype: int64
# ==================== 2024-06 ====================
# word
# freq level_freq
# 4     1885
# 1     1885
# 9     1884
# 10    1884
# 6     1884
# 3     1884
# 7     1884
# 8     1884
# 2     1884
# 5     1883
# Name: count, dtype: int64
# dist level_dist
# 4     11578
# 5      5901
# 3       668
# 6       563
# 2        58
# 7        55
# 8        12
# 10        3
# 9         2
# 1         1
# Name: count, dtype: int64
# app
# freq level_freq
# 3     360
# 1     344
# 7     344
# 10    344
# 2     344
# 5     344
# 9     344
# 6     343
# 8     343
# 4     327
# Name: count, dtype: int64
# dist level_dist
# 4     2024
# 5      895
# 3      276
# 6      120
# 2       62
# 7       29
# 1       20
# 8        6
# 9        3
# 10       2
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 4     2317
# 8     2310
# 1     2301
# 7     2299
# 10    2299
# 3     2299
# 6     2297
# 2     2297
# 9     2287
# 5     2281
# Name: count, dtype: int64
# dist level_dist
# 5     19852
# 6      3024
# 4        85
# 7         8
# 3         6
# 2         4
# 1         4
# 8         2
# 9         1
# 10        1
# Name: count, dtype: int64
# ==================== 2024-07 ====================
# word
# freq level_freq
# 8     1932
# 1     1932
# 4     1931
# 10    1931
# 5     1931
# 2     1931
# 7     1931
# 3     1931
# 6     1931
# 9     1930
# Name: count, dtype: int64
# dist level_dist
# 4     12313
# 3      4561
# 5      1799
# 2       296
# 6       243
# 7        51
# 8        21
# 1        19
# 9         6
# 10        2
# Name: count, dtype: int64
# app
# freq level_freq
# 1     355
# 10    355
# 5     355
# 3     354
# 9     354
# 4     354
# 2     354
# 8     354
# 7     354
# 6     354
# Name: count, dtype: int64
# dist level_dist
# 3     1621
# 4     1546
# 5      194
# 2      115
# 1       25
# 6       25
# 7       13
# 8        2
# 9        1
# 10       1
# Name: count, dtype: int64
# sender
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# freq level_freq
# 8     1951
# 1     1951
# 3     1951
# 10    1950
# 6     1949
# 5     1949
# 7     1949
# 2     1948
# 9     1947
# 4     1947
# Name: count, dtype: int64
# dist level_dist
# 5     11284
# 4      8137
# 8        22
# 3        18
# 6        16
# 1         6
# 2         4
# 7         3
# 9         1
# 10        1
# Name: count, dtype: int64
# ==================== 2024-08 ====================
# word
# freq level_freq
# 9     1885
# 4     1878
# 7     1878
# 1     1878
# 6     1877
# 5     1877
# 3     1877
# 8     1877
# 2     1877
# 10    1870
# Name: count, dtype: int64
# dist level_dist
# 4     8488
# 5     6428
# 3     2636
# 6      738
# 2      229
# 7      151
# 8       58
# 1       29
# 9       15
# 10       2
# Name: count, dtype: int64
# app
# freq level_freq
# 3     421
# 2     410
# 8     410
# 6     410
# 10    410
# 1     410
# 5     409
# 7     409
# 9     409
# 4     398
# Name: count, dtype: int64
# dist level_dist
# 3     2392
# 4     1180
# 2      225
# 5      223
# 1       44
# 6       20
# 7        9
# 10       3
# Name: count, dtype: int64
# sender
# freq level_freq
# 6     2092
# 1     2087
# 8     2083
# 10    2083
# 2     2083
# 5     2083
# 4     2083
# 9     2080
# 3     2078
# 7     2075
# Name: count, dtype: int64
# dist level_dist
# 5     20224
# 4       532
# 6        39
# 3        14
# 7         6
# 1         5
# 2         4
# 10        2
# 9         1
# Name: count, dtype: int64
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
month = '2024-08'
app_config_dir = work_dir / 'app_config_window'
word_config_dir = work_dir / 'word_config_window'
sender_config_dir = work_dir / 'sender_config_window'
overdue_rate_config = generate_word_config_data(calc_month=month,rlevel_bins=10,window_size=3)
overdue_rate_config.to_parquet(word_config_dir / f'word_overdue_rate_window3_{month}.parquet',compression='zstd')
overdue_rate_config = generate_app_config_data(calc_month=month,rlevel_bins=10,window_size=3)
overdue_rate_config.to_parquet(app_config_dir / f'app_overdue_rate_window3_{month}.parquet',compression='zstd')
overdue_rate_config = generate_sender_config_data(calc_month=month,rlevel_bins=10,window_size=3)
overdue_rate_config.to_parquet(sender_config_dir / f'sender_overdue_rate_window3_{month}.parquet',compression='zstd')
# Out:
# freq level_freq
# 5     2311
# 10    2311
# 9     2311
# 6     2311
# 3     2311
# 8     2311
# 7     2311
# 1     2311
# 2     2311
# 4     2311
# Name: count, dtype: int64
# dist level_dist
# 5     11000
# 4      5326
# 6      3588
# 3      2294
# 7       623
# 2       171
# 8        80
# 1        13
# 9        11
# 10        4
# Name: count, dtype: int64
# freq level_freq
# 1     360
# 10    360
# 6     359
# 2     359
# 3     359
# 9     359
# 5     359
# 8     359
# 4     359
# 7     359
# Name: count, dtype: int64
# dist level_dist
# 3     2024
# 4     1127
# 2      189
# 5      185
# 1       43
# 6       19
# 7        2
# 8        2
# 10       1
# Name: count, dtype: int64
# freq level_freq
# 9     1180
# 3     1179
# 4     1179
# 7     1178
# 1     1178
# 8     1177
# 2     1177
# 6     1177
# 10    1175
# 5     1174
# Name: count, dtype: int64
# dist level_dist
# 5     4781
# 4     2863
# 6     1991
# 3     1072
# 7      606
# 2      318
# 8      106
# 1       25
# 9       10
# 10       2
# Name: count, dtype: int64

# %%
app_config_dir = work_dir / 'app_config_window'
if not app_config_dir.exists():
    app_config_dir.mkdir(exist_ok=True)
    
for month in ['2023-06','2023-07','2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07']:
    overdue_rate_config = generate_app_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    overdue_rate_config.to_parquet(app_config_dir / f'app_overdue_rate_window3_{month}.parquet',compression='zstd')
# Out:
# freq level_freq
# 1     357
# 9     357
# 5     357
# 3     356
# 2     356
# 8     356
# 10    356
# 6     356
# 7     356
# 4     356
# Name: count, dtype: int64
# dist level_dist
# 6     1531
# 7     1204
# 8      298
# 5      286
# 9       89
# 4       75
# 3       36
# 10      35
# 2        8
# 1        1
# Name: count, dtype: int64
# freq level_freq
# 7     352
# 9     349
# 3     349
# 1     348
# 5     348
# 2     348
# 6     348
# 10    347
# 4     347
# 8     344
# Name: count, dtype: int64
# dist level_dist
# 6     1730
# 7      939
# 5      398
# 8      219
# 4       85
# 9       54
# 3       25
# 10      17
# 2       12
# 1        1
# Name: count, dtype: int64
# freq level_freq
# 1     367
# 4     367
# 10    367
# 9     367
# 8     367
# 2     367
# 3     367
# 5     367
# 6     367
# 7     367
# Name: count, dtype: int64
# dist level_dist
# 6     1853
# 7      684
# 5      573
# 8      317
# 4      141
# 3       46
# 9       38
# 2       12
# 10       4
# 1        2
# Name: count, dtype: int64
# freq level_freq
# 6     376
# 9     363
# 1     363
# 10    363
# 2     363
# 4     363
# 5     363
# 3     362
# 8     362
# 7     349
# Name: count, dtype: int64
# dist level_dist
# 5     1616
# 6     1279
# 7      286
# 4      245
# 8      119
# 3       49
# 2       18
# 9        8
# 10       5
# 1        2
# Name: count, dtype: int64
# freq level_freq
# 3     376
# 6     374
# 1     367
# 2     367
# 9     366
# 10    366
# 5     366
# 8     365
# 7     359
# 4     355
# Name: count, dtype: int64
# dist level_dist
# 6     2035
# 5      728
# 7      556
# 4      139
# 8      121
# 3       50
# 9       22
# 10       8
# 1        1
# 2        1
# Name: count, dtype: int64
# freq level_freq
# 1     375
# 5     374
# 10    374
# 3     374
# 8     374
# 9     373
# 7     373
# 4     373
# 6     373
# 2     372
# Name: count, dtype: int64
# dist level_dist
# 4     2090
# 5     1062
# 3      296
# 6      185
# 2       47
# 7       31
# 8        9
# 9        7
# 1        7
# 10       1
# Name: count, dtype: int64
# freq level_freq
# 2     377
# 1     374
# 10    374
# 5     374
# 6     373
# 8     373
# 7     373
# 9     373
# 4     373
# 3     369
# Name: count, dtype: int64
# dist level_dist
# 5     1649
# 4     1299
# 6      303
# 3      233
# 7      113
# 2       85
# 8       29
# 1       12
# 9        6
# 10       4
# Name: count, dtype: int64
# freq level_freq
# 4     358
# 7     358
# 1     357
# 10    357
# 6     357
# 2     357
# 9     356
# 3     356
# 5     355
# 8     355
# Name: count, dtype: int64
# dist level_dist
# 4     2015
# 5      911
# 3      305
# 6      172
# 2       93
# 7       35
# 1       20
# 8       10
# 9        3
# 10       2
# Name: count, dtype: int64
# freq level_freq
# 3     346
# 1     345
# 2     345
# 10    345
# 5     345
# 7     345
# 9     345
# 6     344
# 8     344
# 4     343
# Name: count, dtype: int64
# dist level_dist
# 5     1478
# 4     1279
# 6      287
# 3      244
# 7       77
# 2       53
# 8       13
# 1        7
# 9        5
# 10       4
# Name: count, dtype: int64
# freq level_freq
# 3     339
# 5     338
# 9     336
# 1     336
# 2     336
# 10    336
# 7     336
# 8     336
# 4     333
# 6     333
# Name: count, dtype: int64
# dist level_dist
# 5     1436
# 4     1293
# 6      272
# 3      206
# 7       66
# 2       52
# 8       17
# 1       13
# 10       2
# 9        2
# Name: count, dtype: int64
# freq level_freq
# 1     344
# 4     344
# 6     344
# 8     344
# 2     344
# 9     344
# 3     343
# 10    343
# 5     343
# 7     343
# Name: count, dtype: int64
# dist level_dist
# 4     2032
# 5      831
# 3      291
# 6      173
# 2       58
# 7       31
# 9       10
# 1        7
# 8        2
# 10       1
# Name: count, dtype: int64

# %%
sender_config_dir = work_dir / 'sender_config_window'
if not sender_config_dir.exists():
    sender_config_dir.mkdir(exist_ok=True)

for month in ['2023-06','2023-07','2023-08','2023-09','2023-10','2023-11','2023-12','2024-01','2024-02','2024-03','2024-04','2024-05','2024-06','2024-07']:
    overdue_rate_config = generate_sender_config_data(calc_month=month,rlevel_bins=10,window_size=3)
    overdue_rate_config.to_parquet(sender_config_dir / f'sender_overdue_rate_window3_{month}.parquet',compression='zstd')
# Out:
# freq level_freq
# 5     1289
# 2     1287
# 1     1287
# 9     1286
# 4     1286
# 7     1285
# 8     1284
# 6     1284
# 10    1283
# 3     1282
# Name: count, dtype: int64
# dist level_dist
# 5     4164
# 4     3884
# 6     1886
# 3     1719
# 7      503
# 2      437
# 8      166
# 1       63
# 9       28
# 10       3
# Name: count, dtype: int64
# freq level_freq
# 1     654
# 4     653
# 10    652
# 9     651
# 7     651
# 8     651
# 6     651
# 5     650
# 3     650
# 2     650
# Name: count, dtype: int64
# dist level_dist
# 5     2355
# 4     1801
# 6     1215
# 3      507
# 7      322
# 8      169
# 2       88
# 9       40
# 1       11
# 10       5
# Name: count, dtype: int64
# freq level_freq
# 10    431
# 7     431
# 1     431
# 4     431
# 8     430
# 9     430
# 2     430
# 5     430
# 6     430
# 3     430
# Name: count, dtype: int64
# dist level_dist
# 5     1351
# 4     1140
# 6      799
# 3      457
# 7      291
# 8      121
# 2       68
# 9       61
# 1        8
# 10       8
# Name: count, dtype: int64
# freq level_freq
# 1     288
# 9     287
# 10    287
# 8     287
# 6     287
# 3     287
# 7     287
# 5     287
# 2     287
# 4     287
# Name: count, dtype: int64
# dist level_dist
# 5     1056
# 4      900
# 6      418
# 3      348
# 7       87
# 2       40
# 8       16
# 1        2
# 9        2
# 10       2
# Name: count, dtype: int64
# freq level_freq
# 7     575
# 3     571
# 5     571
# 1     571
# 9     570
# 10    570
# 4     570
# 2     569
# 6     568
# 8     564
# Name: count, dtype: int64
# dist level_dist
# 5     1857
# 4     1572
# 6     1139
# 3      584
# 7      336
# 2      106
# 8       71
# 9       17
# 1       12
# 10       5
# Name: count, dtype: int64
# freq level_freq
# 5     769
# 9     767
# 1     767
# 2     767
# 8     766
# 10    766
# 4     766
# 7     766
# 3     766
# 6     763
# Name: count, dtype: int64
# dist level_dist
# 4     2742
# 3     2145
# 5     1336
# 2      680
# 6      524
# 7      138
# 1       67
# 8       23
# 9        5
# 10       3
# Name: count, dtype: int64
# freq level_freq
# 4     1545
# 1     1544
# 2     1544
# 10    1543
# 5     1543
# 8     1543
# 9     1542
# 7     1542
# 3     1540
# 6     1539
# Name: count, dtype: int64
# dist level_dist
# 5     7660
# 6     4218
# 4     2365
# 7      853
# 8      172
# 3       98
# 9       42
# 2        9
# 10       7
# 1        1
# Name: count, dtype: int64
# freq level_freq
# 3     1364
# 7     1363
# 5     1363
# 8     1361
# 1     1361
# 10    1360
# 2     1360
# 9     1357
# 4     1357
# 6     1357
# Name: count, dtype: int64
# dist level_dist
# 5     5734
# 6     3377
# 4     3130
# 7      800
# 3      410
# 8      109
# 2       21
# 9       15
# 10       4
# 1        3
# Name: count, dtype: int64
# freq level_freq
# 6     1344
# 8     1342
# 3     1342
# 4     1342
# 1     1341
# 10    1341
# 2     1341
# 9     1339
# 7     1337
# 5     1337
# Name: count, dtype: int64
# dist level_dist
# 6     4718
# 5     4674
# 7     1887
# 4     1664
# 8      346
# 3       69
# 9       31
# 2        8
# 10       6
# 1        3
# Name: count, dtype: int64
# freq level_freq
# 1     1388
# 4     1388
# 3     1385
# 9     1385
# 10    1384
# 7     1384
# 8     1384
# 6     1383
# 2     1381
# 5     1380
# Name: count, dtype: int64
# dist level_dist
# 4     5463
# 5     3129
# 3     2835
# 6     1038
# 2      904
# 7      294
# 1      125
# 8       46
# 10       4
# 9        4
# Name: count, dtype: int64
# freq level_freq
# 2     1279
# 6     1270
# 9     1269
# 10    1269
# 4     1269
# 5     1269
# 1     1269
# 8     1268
# 7     1267
# 3     1258
# Name: count, dtype: int64
# dist level_dist
# 5     4207
# 4     3649
# 6     1800
# 3     1623
# 7      640
# 2      550
# 8      160
# 1       37
# 9       17
# 10       4
# Name: count, dtype: int64

# %%
overdue_rate_config.head()
# Out:
#                               app  bad_count  total_count  overdue_rate  \
# 0                    acb2b.app.pr         58          213      0.272300
# 1  agency.equilibrio.sodexomexico       1042         2743      0.379876
# 2          ai.bohemian.multipolls        121          239      0.506276
# 3                ai.powerup.stori       6490        17258      0.376057
# 4                   air.cinepolis       2479         6482      0.382444
#
#   overdue_bin_freq  level_freq overdue_bin_dist  level_dist
# 0    (0.224, 0.36]           1    (0.27, 0.316]           2
# 1   (0.374, 0.382]           3   (0.361, 0.406]           4
# 2   (0.436, 0.678]          10   (0.497, 0.542]           7
# 3   (0.374, 0.382]           3   (0.361, 0.406]           4
# 4   (0.382, 0.387]           4   (0.361, 0.406]           4

# %%
# 内存占用大小 
overdue_rate_config.memory_usage().sum() / 1024 / 1024
# Out:
# 0.6050891876220703

# %% [markdown]
# # 新方法

# %%
def data_of_dir(dir_path: str, contains_flags="", start_date='2023-01-01', end_date='2999-01-01'):
    """
    获取指定目录下的文件
    :param dir_path:  目录路径
    :param contains_flags: 包含的标志
    :param start_date:  开始日期
    :param end_date:  结束日期
    :return: 
    """
    def _fetch_filenams(dir_path: str, contain_flag, start_date=None, end_date=None):
        file_paths = []
        contain_flag = contain_flag or ""
        pattern = r"\d{4}-\d{2}-\d{2}"
        for file_name in os.listdir(dir_path):
            if (contain_flag in file_name) and (
            file_name.endswith(('.pqt', '.parquet', '.csv', '.xlsx', '.pickle', '.pkl'))):
                if start_date is None:
                    file_paths.append(os.path.join(dir_path, file_name))
                else:
                    match = re.search(pattern, file_name)
                    date = match.group()  # type: ignore
                    if (date >= start_date) and (date < end_date):
                        file_paths.append(os.path.join(dir_path, file_name))
        file_paths.sort()
        return file_paths

    if isinstance(contains_flags, str) or contains_flags is None:
        return _fetch_filenams(dir_path, contains_flags, start_date, end_date)
    elif isinstance(contains_flags, list):
        file_names = None
        for contains_flag in contains_flags:  # type: ignore
            if file_names is None:
                file_names = _fetch_filenams(dir_path, contains_flag, start_date, end_date)
            else:
                file_names = file_names + _fetch_filenams(dir_path, contains_flag, start_date, end_date)
        return file_names

# %%
def parse_json_data(df, json_column, id_column, retain_column=None):
    new_rows = []
    for i, row in df.iterrows():
        json_data_str = row[json_column]
        id_column_value = row[id_column]
        if isinstance(json_data_str, str) and len(json_data_str.strip())>0 :
            try:
                json_data = json.loads(json_data_str)
                for item in json_data:
                    new_row = item
                    new_row[id_column] = id_column_value
                    if isinstance(retain_column, str) and len(retain_column) > 0:
                        new_row[retain_column] = row[retain_column]
                    elif isinstance(retain_column, list) and len(retain_column) > 0:
                        for column in retain_column:
                            new_row[column] = row[column]
                    new_rows.append(new_row)
            except Exception as e:
                print(f"异常数据 {id_column_value}:{traceback.format_exc()}")
                continue
    new_df = pd.DataFrame(new_rows)
    return new_df

# %%
def parallel_process(task_function,task_list,process_num=10):
    """
    task_function : 任务函数
    task_list : 任务列表
    """
    start_time = time.time()
    def _task(task_function,queue,task_params):
        try:
            task_function(*task_params)
        finally:
            queue.put(True)
    from multiprocessing import Queue, Process
    mp_queue = Queue()
    for i in range(process_num):
        mp_queue.put(True)
    for task_params in tqdm(task_list):
        mp_queue.get()
        Process(target=_task,args=(task_function,mp_queue,task_params)).start() # mq_queue 用于控制进程数
    for i in range(process_num):
        mp_queue.get()
    mp_queue.close()
    gc.collect()
    print(f'任务完成，总计{len(task_list)}个任务,耗时{time.time()-start_time}s')

# %%
import time
from multiprocessing import Queue, Process
from tqdm import tqdm

def parallel_process(task_function, task_list, process_num=10):
    """
    task_function : 任务函数
    task_list : 任务列表
    """
    start_time = time.time()
    
    def _task(task_function, queue, task_params):
        try:
            task_function(*task_params)
        finally:
            queue.put(True)
            pid = os.getpid()
            print(f'进程{pid}完成')
            # kill pid
            os.system(f'kill -9 {pid}')
    
    mp_queue = Queue()
    
    for i in range(process_num):
        mp_queue.put(True)
    
    processes = []
    
    for task_params in tqdm(task_list):
        mp_queue.get()
        p = Process(target=_task, args=(task_function, mp_queue, task_params))
        p.start()
        processes.append(p)
    
    for p in processes:
        p.join()
    
    mp_queue.close()
    gc.collect()
    
    print(f'任务完成，总计{len(task_list)}个任务,耗时{time.time()-start_time}s')

# %%
import time
from multiprocessing import Pool
from tqdm import tqdm

def parallel_process(task_function, task_list, process_num=10):
    """
    task_function : 任务函数
    task_list : 任务列表
    """
    start_time = time.time()
    
    with Pool(processes=process_num) as pool:
        results = list(tqdm(pool.imap(task_function, task_list), total=len(task_list)))
    
    print(f'任务完成，总计{len(task_list)}个任务,耗时{time.time()-start_time}s')
    return results

# %% [markdown]
# # woe 配置文件计算

# %% [markdown]
# ## 先计算每一天的applist的bad数、order数、user数

# %%
# 业务逻辑，读取指定目录的文件，然后解析其中的applist，再计算出其对应的月份的woe的切片
def computer_app_woe_daily(file_path:str,save_path:str):
    try:
        raw_df = pd.read_parquet(file_path) # 
        raw_df['apply_month'] = raw_df['apply_time'].dt.strftime('%Y-%m')
        raw_df['bad'] = np.where(raw_df['agr_pd7']==1,raw_df['def_pd7'],None)
        df = raw_df[raw_df['bad'].notnull()]
        if len(df) == 0:
            return 0
        user_apps = parse_json_data(df,'applist_data','app_order_id',['apply_month','bad','apply_time','user_id'])
        tmp_arr = []
        for key,grp in user_apps.groupby(['apply_month','app_package']):
            apply_month,app_package = key
            rs = {}
            bad = grp['bad'].sum()
            order = grp['bad'].count()
            user = grp['user_id'].nunique()
            rs['apply_month'] = apply_month
            rs['app_package'] = app_package
            rs['bad'] = bad
            rs['order'] = order
            rs['user'] = user
            rs['app_name'] = ';'.join(grp['app_name'].unique())
            tmp_arr.append(rs)
        df = pd.DataFrame(tmp_arr)
        df.to_parquet(save_path,compression='zstd')
        return 0 
    except:
        print(f'{file_path}计算失败 \n', traceback.format_exc())
        return 1

# %%
tmp_dir = work_dir/'applist_tmp' # 设定计算结果保存的路径
if not tmp_dir.exists():
    tmp_dir.mkdir()
file_paths = data_of_dir(raw_dir,['_YM','_M','_AM'])
task_list = [ (x,  str(tmp_dir/x.split('/')[-1]) )  for x in file_paths ]  # 生成任务的参数列表,[('/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-16.pqt','/home/mayongzhi/marshall/sender_word_call_app/applist_tmp/raw_YM_2023-08-16.pqt'),  ...]
parallel_process(computer_app_woe_daily,task_list,46)

# %%
# 查看计算结果
files = list(tmp_dir.glob('*'))
df = pd.read_parquet(files[0])
df.head()
# Out:
#   apply_month                               app_package  bad  order  user  \
# 0     2023-08  abunda.unox.tasew.mbak.ssqc.bbva.cfiqoza    1      3     3
# 1     2023-08                          ai.powerup.stori    5      9     9
# 2     2023-08                             air.Cinepolis    1      1     1
# 3     2023-08          air.com.cetesdirecto.cetesmobile    1      1     1
# 4     2023-08                                   android   17     27    27
#
#           app_name
# 0        Abundance
# 1            Stori
# 2        Cinépolis
# 3     cetesdirecto
# 4  Sistema Android

# %%
from concurrent.futures import ProcessPoolExecutor
with ProcessPoolExecutor(16) as executor:
    # 使用 list comprehension 来收集结果
    results = list(tqdm(executor.map(pd.read_parquet, files), total=len(files)))

# 合并所有结果
app_woe_info_20240827 = pd.concat(results, ignore_index=True)

# 进行 groupby 和聚合操作
app_woe_info_20240827 = app_woe_info_20240827.groupby(['apply_month', 'app_package', 'app_name']).agg({
    'bad': 'sum',
    'order': 'sum',
    'user': 'sum'
}).reset_index()
# Out:
# 100%|██████████| 1214/1214 [00:03<00:00, 347.07it/s]

# %%
app_woe_info_20240827.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 app_woe_info_20240827.shape
#
# NameError: name 'app_woe_info_20240827' is not defined

# %%
app_woe_info_20240827.head()
# Out:
#   apply_month      app_package  bad  order  user
# 0     2023-01    Adavan.CACInv    0      2     2
# 1     2023-01    Adavan.PyCCAC    0      2     2
# 2     2023-01  CFE.CAsistencia    0      1     1
# 3     2023-01          CMG.GMF    0      1     1
# 4     2023-01    DOCECG.Doctor    0      4     4

# %%
print(app_woe_info_20240827.dtypes)
# Out:
# apply_month    object
# app_name       object
# bad             int64
# order           int64
# user            int64
# dtype: object

# %%
app_woe_monthly.to_parquet(work_dir/'app_woe_info20240827.pqt',compression='zstd')

# %%
tmp_dir = work_dir/'applist_tmp'
list_of_M = data_of_dir(tmp_dir, '_M') # 获取所有的M文件
print(len(list_of_M))
# Out:
# 584

# %%
raw_M_20240827_df = pd.DataFrame()
for raw_file in data_of_dir(raw_dir,'_M_'):
    # 不读'applis_data'列和‘sms_data’列
    raw_file_df = pd.read_parquet(raw_file, columns=['apply_time','agr_pd7','def_pd7','user_id'])
    raw_M_20240827_df = pd.concat([raw_M_20240827_df,raw_file_df])
raw_M_20240827_df.to_parquet(work_dir/'raw_M_20240827.pqt',compression='zstd')

# %%
raw_AM_20240827_df = pd.DataFrame()
for raw_file in data_of_dir(raw_dir,'_AM_'):
    raw_file_df = pd.read_parquet(raw_file, columns=['apply_time','agr_pd7','def_pd7','user_id'])
    raw_AM_20240827_df = pd.concat([raw_AM_20240827_df,raw_file_df])
raw_AM_20240827_df.to_parquet(work_dir/'raw_AM_20240827.pqt',compression='zstd')

raw_YM_20240827_df = pd.DataFrame()
for raw_file in data_of_dir(raw_dir,'_YM_'):
    raw_file_df = pd.read_parquet(raw_file, columns=['apply_time','agr_pd7','def_pd7','user_id'])
    raw_YM_20240827_df = pd.concat([raw_YM_20240827_df,raw_file_df])
raw_YM_20240827_df.to_parquet(work_dir/'raw_YM_20240827.pqt',compression='zstd')

# %% [markdown]
# ## 根据窗口计算woe特性的配置文件

# %%
calc_month = ['2023-10', '2023-11', '2023-12','2024-01', '2024-02',
              '2024-03', '2024-04', '2024-05', '2024-06','2024-07', '2024-08']

# %%
raw_df_m = pd.read_parquet(work_dir/'raw_M_20240827.pqt')
raw_df_ym = pd.read_parquet(work_dir/'raw_YM_20240827.pqt')
raw_df_am = pd.read_parquet(work_dir/'raw_AM_20240827.pqt')
raw_df_ym['apply_month'] = raw_df_ym['apply_time'].dt.strftime('%Y-%m')
raw_df_m['apply_month'] = raw_df_m['apply_time'].dt.strftime('%Y-%m')
raw_df_am['apply_month'] = raw_df_am['apply_time'].dt.strftime('%Y-%m')
brate_ym=raw_df_ym.groupby('apply_month').agg({
    'def_pd7':'sum',
    'agr_pd7':'sum',
})
brate_m=raw_df_m.groupby('apply_month').agg({
    'def_pd7':'sum',
    'agr_pd7':'sum',
})
brate_am=raw_df_am.groupby('apply_month').agg({
    'def_pd7':'sum',
    'agr_pd7':'sum',
})
brate_df = pd.concat([brate_m, brate_ym, brate_am]).groupby(level=0).sum()
brate_df['brate'] = brate_df['def_pd7']/brate_df['agr_pd7'] # apply_month,def_pd7,agr_pd7,brate

# %%
brate_df
# Out:
#              def_pd7  agr_pd7     brate
# apply_month
# 2023-01        15185    36151  0.420044
# 2023-02         9057    23574  0.384194
# 2023-03        11506    27719  0.415094
# 2023-04        15567    35852  0.434202
# 2023-05        11907    29663  0.401409
# 2023-06        10076    21516  0.468303
# 2023-07        18954    35067  0.540508
# 2023-08        12157    27531  0.441575
# 2023-09         9312    24867  0.374472
# 2023-10        10211    26521  0.385016
# 2023-11        11495    28447  0.404085
# 2023-12        12662    29578  0.428088
# 2024-01        10399    26411  0.393737
# 2024-02         9813    24992  0.392646
# 2024-03         8047    22198  0.362510
# 2024-04         8820    22020  0.400545
# 2024-05        14805    33373  0.443622
# 2024-06        24409    55491  0.439873
# 2024-07        15323    34728  0.441229
# 2024-08         2480     5796  0.427881

# %%
example_file = files[0]
pd.read_parquet(example_file).head()
# Out:
#     id              user_id acq_channel         app_order_id  \
# 1  363  1171937404689764352        ADNF  1171937419898310656
#
#            contract_no repayment_date  installment_num  installment_amount  \
# 1  1171937432632217600     2023-11-14                1               155.0
#
#    principal  interest  ...  is_extension       app_order_id_x  repaid  \
# 1      145.0      10.0  ...             0  1171937419898310656   155.0
#
#    payout  profit  def_ltv              file_name  call_log_data  \
# 1  2213.0 -2058.0        1  raw_AM_2023-11-08.pqt             []
#
#                                         applist_data  \
# 1  [{"app_name":"com.android.cts.priv.ctsshim","a...
#
#                                             sms_data
# 1  [{"body":"[FinMex] 3497 es su codigo de verifi...
#
# [1 rows x 91 columns]

# %%
# 生成任务的参数列表
tmp_dir = work_dir/'applist_tmp' # 设定计算结果保存的路径
if not tmp_dir.exists():
    tmp_dir.mkdir()
file_paths = data_of_dir(raw_dir,['_YM','_M','_AM'])
task_list = [ (x,  str(tmp_dir/x.split('/')[-1]) )  for x in file_paths ]

# 同时开始46个进程执行任务
parallel_process(computer_app_woe_daily,task_list,46)

# %% [markdown]
# ### 3个月滑动窗口

# %%
app_woe_monthly.head()
# Out:
#   apply_month      app_package  bad  order  user
# 0     2023-01    Adavan.CACInv    0      2     2
# 1     2023-01    Adavan.PyCCAC    0      2     2
# 2     2023-01  CFE.CAsistencia    0      1     1
# 3     2023-01          CMG.GMF    0      1     1
# 4     2023-01    DOCECG.Doctor    0      4     4

# %%
window_size = 3
level_num = 10
app_woe_window_df = pd.DataFrame()
app_woe_window_list = []
for month, end_month, start_month in tqdm(month_window(calc_month,window_size)):
    window_df = app_woe_monthly[(app_woe_monthly['apply_month'] >= start_month) & (app_woe_monthly['apply_month'] <= end_month)]   # 窗口内的所有app
    window_brate_df = brate_df[(brate_df.index >= start_month) & (brate_df.index <= end_month)] # 月逾期率
    brate_total = window_brate_df['def_pd7'].sum() / window_brate_df['agr_pd7'].sum()
    print(f'window_df:{window_df.shape}')
    print('brate_total:',brate_total)
    grouped = window_df.groupby('app_package').agg({
        'bad':'sum',
        'order':'sum',
        'apply_month':'nunique'
    }).reset_index()
    grouped['brate'] = grouped['bad'] / grouped['order']
    grouped['woe'] = np.where(
        (grouped['brate'] == 0) | (grouped['brate'] == 1),
        0,
        np.log((grouped['brate'] / brate_total) / ((1 - grouped['brate']) / (1 - brate_total) + 1e-6))
    )
    grouped['woe'] = grouped['woe'].round(4)
    grouped.rename(columns={'apply_month':'month_nums'},inplace=True)
    grouped['apply_month'] = month
    app_woe_window_list.append(grouped)
app_woe_window_df = pd.concat(app_woe_window_list, ignore_index=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   9%|▉         | 1/11 [00:00<00:01,  5.19it/s]
# window_df:(157930, 5)
# brate_total: 0.46216200766020693
# window_df:(154620, 5)
# brate_total: 0.4014242451120769
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  18%|█▊        | 2/11 [00:00<00:01,  5.36it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  27%|██▋       | 3/11 [00:00<00:01,  5.38it/s]
# window_df:(144945, 5)
# brate_total: 0.38852633556710714
# window_df:(145036, 5)
# brate_total: 0.4065006032219147
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  36%|███▋      | 4/11 [00:00<00:01,  5.35it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  45%|████▌     | 5/11 [00:00<00:01,  5.35it/s]
# window_df:(142636, 5)
# brate_total: 0.40925671514519874
# window_df:(140601, 5)
# brate_total: 0.4059470740050135
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  55%|█████▍    | 6/11 [00:01<00:00,  5.37it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  64%|██████▎   | 7/11 [00:01<00:00,  5.38it/s]
# window_df:(136515, 5)
# brate_total: 0.383948587655059
# window_df:(133742, 5)
# brate_total: 0.38549342580551943
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  73%|███████▎  | 8/11 [00:01<00:00,  5.43it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  82%|████████▏ | 9/11 [00:01<00:00,  5.37it/s]
# window_df:(142065, 5)
# brate_total: 0.408191671714503
# window_df:(170498, 5)
# brate_total: 0.4331914433101259
# /home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  91%|█████████ | 10/11 [00:01<00:00,  5.12it/s]/home/mayongzhi/miniconda3/envs/myz311/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|██████████| 11/11 [00:02<00:00,  5.17it/s]
# window_df:(182629, 5)
# brate_total: 0.44126642501132757

# %%
app_woe_window_df.head()
# Out:
#         app_package  bad  order  month_nums  brate     woe apply_month
# 0           7.0.9.1    0      1           1    0.0  0.0000     2023-10
# 1   r_aml_301400200    1      1           1    1.0  0.0000     2023-10
# 2                 -    1      2           2    0.5  0.1516     2023-10
# 3                 0    1      1           1    1.0  0.0000     2023-10
# 4             0.0.0    1      2           1    0.5  0.1516     2023-10

# %%
app_woe_window_df[app_woe_window_df['month_nums']>1].shape
# Out:
# (422124, 7)

# %%
app_woe_window_df[app_woe_window_df['month_nums'] == window_size].shape
# Out:
# (256544, 7)

# %%
app_woe_window_df[app_woe_window_df['woe'] < 0 ].shape
# Out:
# (184282, 7)

# %%
tmp = []
for apply_month,grp in app_woe_window_df.groupby('apply_month'):
    print(grp[grp['month_nums'] == window_size].shape)
    condition = (grp['month_nums'] == window_size)  & (grp['order'] > 50)
    grp = grp[condition].copy()
    print(apply_month, len(grp))
    if len(grp) > level_num:
        grp.loc[:,'woe_bin_freq'] = pd.qcut(grp['woe'],level_num,duplicates='drop')
        grp.loc[:,'level_freq'] = grp['woe_bin_freq'].cat.codes+1
        grp.loc[:,'woe_bin_dist'] = pd.cut(grp['woe'],level_num,duplicates='drop')
        grp.loc[:,'level_dist'] = grp['woe_bin_dist'].cat.codes+1
        tmp.append(grp)
        print('freq',grp['level_freq'].value_counts().sort_index())
        print('dist',grp['level_dist'].value_counts().sort_index())
    print('='*20)
app_woe_config = pd.concat(tmp)
# Out:
# (23457, 7)
# 2023-10 7584
# freq level_freq
# 1     759
# 2     758
# 3     758
# 4     759
# 5     760
# 6     756
# 7     759
# 8     759
# 9     757
# 10    759
# Name: count, dtype: int64
# dist level_dist
# 1        3
# 2       22
# 3      121
# 4      595
# 5     2926
# 6     3001
# 7      788
# 8      108
# 9       17
# 10       3
# Name: count, dtype: int64
# ====================
# (23018, 7)
# 2023-11 7221
# freq level_freq
# 1     736
# 2     720
# 3     735
# 4     698
# 5     723
# 6     721
# 7     723
# 8     725
# 9     724
# 10    716
# Name: count, dtype: int64
# dist level_dist
# 1        1
# 2        7
# 3       35
# 4      174
# 5      861
# 6     4088
# 7     1708
# 8      289
# 9       45
# 10      13
# Name: count, dtype: int64
# ====================
# (22381, 7)
# 2023-12 7318
# freq level_freq
# 1     732
# 2     734
# 3     731
# 4     733
# 5     729
# 6     732
# 7     731
# 8     732
# 9     733
# 10    731
# Name: count, dtype: int64
# dist level_dist
# 1        6
# 2       37
# 3      255
# 4     1385
# 5     4250
# 6     1204
# 7      155
# 8       18
# 9        6
# 10       2
# Name: count, dtype: int64
# ====================
# (22532, 7)
# 2024-01 7566
# freq level_freq
# 1     769
# 2     745
# 3     759
# 4     758
# 5     755
# 6     755
# 7     755
# 8     757
# 9     756
# 10    757
# Name: count, dtype: int64
# dist level_dist
# 1       26
# 2      278
# 3     3448
# 4     3381
# 5      323
# 6       83
# 7       12
# 8        7
# 9        5
# 10       3
# Name: count, dtype: int64
# ====================
# (22484, 7)
# 2024-02 7647
# freq level_freq
# 1     765
# 2     765
# 3     765
# 4     766
# 5     767
# 6     760
# 7     766
# 8     763
# 9     806
# 10    724
# Name: count, dtype: int64
# dist level_dist
# 1        3
# 2      126
# 3     3171
# 4     4044
# 5      230
# 6       51
# 7        7
# 8        6
# 9        7
# 10       2
# Name: count, dtype: int64
# ====================
# (22159, 7)
# 2024-03 7454
# freq level_freq
# 1     747
# 2     744
# 3     746
# 4     745
# 5     748
# 6     744
# 7     744
# 8     746
# 9     748
# 10    742
# Name: count, dtype: int64
# dist level_dist
# 1        2
# 2       48
# 3     1030
# 4     5450
# 5      788
# 6       90
# 7       31
# 8        6
# 9        4
# 10       5
# Name: count, dtype: int64
# ====================
# (21641, 7)
# 2024-04 7108
# freq level_freq
# 1     711
# 2     711
# 3     712
# 4     709
# 5     712
# 6     712
# 7     715
# 8     706
# 9     712
# 10    708
# Name: count, dtype: int64
# dist level_dist
# 1        5
# 2       40
# 3      261
# 4      921
# 5     3776
# 6     1642
# 7      350
# 8       86
# 9       17
# 10      10
# Name: count, dtype: int64
# ====================
# (21395, 7)
# 2024-05 6864
# freq level_freq
# 1     687
# 2     686
# 3     686
# 4     688
# 5     686
# 6     689
# 7     724
# 8     645
# 9     686
# 10    687
# Name: count, dtype: int64
# dist level_dist
# 1        3
# 2       15
# 3      117
# 4      680
# 5     3746
# 6     1911
# 7      303
# 8       67
# 9       21
# 10       1
# Name: count, dtype: int64
# ====================
# (22506, 7)
# 2024-06 7276
# freq level_freq
# 1     728
# 2     728
# 3     727
# 4     729
# 5     726
# 6     728
# 7     727
# 8     728
# 9     727
# 10    728
# Name: count, dtype: int64
# dist level_dist
# 1        5
# 2       26
# 3      166
# 4     1066
# 5     4628
# 6     1156
# 7      177
# 8       41
# 9        8
# 10       3
# Name: count, dtype: int64
# ====================
# (25968, 7)
# 2024-07 8674
# freq level_freq
# 1     869
# 2     870
# 3     866
# 4     865
# 5     867
# 6     867
# 7     877
# 8     861
# 9     925
# 10    807
# Name: count, dtype: int64
# dist level_dist
# 1        8
# 2       65
# 3      442
# 4     2382
# 5     4522
# 6     1055
# 7      177
# 8       20
# 10       3
# Name: count, dtype: int64
# ====================
# (29003, 7)
# 2024-08 9239
# freq level_freq
# 1     924
# 2     924
# 3     924
# 4     925
# 5     923
# 6     923
# 7     924
# 8     927
# 9     921
# 10    924
# Name: count, dtype: int64
# dist level_dist
# 1        5
# 2       61
# 3      305
# 4     1440
# 5     5136
# 6     1856
# 7      367
# 8       63
# 9        3
# 10       3
# Name: count, dtype: int64
# ====================

# %%
app_woe_config[app_woe_config['apply_month'] == '2024-05'].head(30)
# Out:
#                                               app_package   bad  order  \
# 605400                                       acb2b.app.pr    70    232
# 605412                                  actinver.bursanet    66    206
# 605424                       addon.sprd.browser.plugindrm    43    105
# 605426                   addon.sprd.documentsui.plugindrm    44    109
# 605427                        addon.sprd.downloadprovider    38    123
# 605440        advanced.scientific.calculator.calc991.plus    34    103
# 605457                     agency.equilibrio.sodexomexico   936   2564
# 605474                             ai.bohemian.multipolls    90    181
# 605502                                          ai.moises    85    198
# 605504                   ai.mybuddy.talkingflashcards_new    40    112
# 605509                       ai.photo.enhancer.photoclear   124    287
# 605515                                   ai.powerup.stori  5600  15736
# 605519                                 ai.reimage.remodel    20     56
# 605523                          ai.socialapps.speakmaster    26     76
# 605538                                      air.Cinepolis  2034   5782
# 605553                                 air.SamsClubMexico  1220   3698
# 605565                         air.br.com.conquian.mobile    48    114
# 605592                           air.com.aceviral.motox3m    15     55
# 605608              air.com.buffalo_studios.newflashbingo    34     92
# 605609                   air.com.cetesdirecto.cetesmobile   223    635
# 605669                           air.com.hypah.io.slither    57    153
# 605692                           air.com.lunime.gachaclub    35    105
# 605693                           air.com.lunime.gachalife    56    145
# 605694                          air.com.lunime.gachalife2    18     57
# 605710                          air.com.myheritage.mobile    23     63
# 605720             air.com.pipastudios.release.praiabingo    31     54
# 605726                        air.com.playtika.slotomania    40    119
# 605936  albums.gallery.photo.folder.picasa.app.web.gal...    33     82
# 605945  alice.music.downloader.download.mp3.music.song...    21     56
# 605951        all.documentreader.filereader.office.viewer   470   1409
#
#         month_nums     brate     woe apply_month  \
# 605400           3  0.301724 -0.3728     2024-05
# 605412           3  0.320388 -0.2857     2024-05
# 605424           3  0.409524  0.1004     2024-05
# 605426           3  0.403670  0.0761     2024-05
# 605427           3  0.308943 -0.3388     2024-05
# 605440           3  0.330097 -0.2415     2024-05
# 605457           3  0.365055 -0.0872     2024-05
# 605474           3  0.497238  0.4552     2024-05
# 605502           3  0.429293  0.1816     2024-05
# 605504           3  0.357143 -0.1215     2024-05
# 605509           3  0.432056  0.1928     2024-05
# 605515           3  0.355872 -0.1270     2024-05
# 605519           3  0.357143 -0.1215     2024-05
# 605523           3  0.342105 -0.1876     2024-05
# 605538           3  0.351781 -0.1449     2024-05
# 605553           3  0.329908 -0.2423     2024-05
# 605565           3  0.421053  0.1478     2024-05
# 605592           3  0.272727 -0.5145     2024-05
# 605608           3  0.369565 -0.0678     2024-05
# 605609           3  0.351181 -0.1476     2024-05
# 605669           3  0.372549 -0.0550     2024-05
# 605692           3  0.333333 -0.2269     2024-05
# 605693           3  0.386207  0.0030     2024-05
# 605694           3  0.315789 -0.3069     2024-05
# 605710           3  0.365079 -0.0871     2024-05
# 605720           3  0.574074  0.7648     2024-05
# 605726           3  0.336134 -0.2143     2024-05
# 605936           3  0.402439  0.0710     2024-05
# 605945           3  0.375000 -0.0445     2024-05
# 605951           3  0.333570 -0.2258     2024-05
#
#                          woe_bin_freq  level_freq      woe_bin_dist  \
# 605400  (-1.6749999999999998, -0.344]           1  (-0.648, -0.306]
# 605412               (-0.344, -0.196]           2  (-0.306, 0.0354]
# 605424                (0.0608, 0.124]           8   (0.0354, 0.377]
# 605426                (0.0608, 0.124]           8   (0.0354, 0.377]
# 605427               (-0.344, -0.196]           2  (-0.648, -0.306]
# 605440               (-0.344, -0.196]           2  (-0.306, 0.0354]
# 605457              (-0.122, -0.0814]           4  (-0.306, 0.0354]
# 605474                 (0.264, 1.745]          10    (0.377, 0.719]
# 605502                 (0.124, 0.264]           9   (0.0354, 0.377]
# 605504              (-0.122, -0.0814]           4  (-0.306, 0.0354]
# 605509                 (0.124, 0.264]           9   (0.0354, 0.377]
# 605515               (-0.196, -0.122]           3  (-0.306, 0.0354]
# 605519              (-0.122, -0.0814]           4  (-0.306, 0.0354]
# 605523               (-0.196, -0.122]           3  (-0.306, 0.0354]
# 605538               (-0.196, -0.122]           3  (-0.306, 0.0354]
# 605553               (-0.344, -0.196]           2  (-0.306, 0.0354]
# 605565                 (0.124, 0.264]           9   (0.0354, 0.377]
# 605592  (-1.6749999999999998, -0.344]           1  (-0.648, -0.306]
# 605608             (-0.0814, -0.0398]           5  (-0.306, 0.0354]
# 605609               (-0.196, -0.122]           3  (-0.306, 0.0354]
# 605669             (-0.0814, -0.0398]           5  (-0.306, 0.0354]
# 605692               (-0.344, -0.196]           2  (-0.306, 0.0354]
# 605693              (-0.0002, 0.0608]           7  (-0.306, 0.0354]
# 605694               (-0.344, -0.196]           2  (-0.648, -0.306]
# 605710              (-0.122, -0.0814]           4  (-0.306, 0.0354]
# 605720                 (0.264, 1.745]          10    (0.719, 1.061]
# 605726               (-0.344, -0.196]           2  (-0.306, 0.0354]
# 605936                (0.0608, 0.124]           8   (0.0354, 0.377]
# 605945             (-0.0814, -0.0398]           5  (-0.306, 0.0354]
# 605951               (-0.344, -0.196]           2  (-0.306, 0.0354]
#
#         level_dist
# 605400           4
# 605412           5
# 605424           6
# 605426           6
# 605427           4
# 605440           5
# 605457           5
# 605474           7
# 605502           6
# 605504           5
# 605509           6
# 605515           5
# 605519           5
# 605523           5
# 605538           5
# 605553           5
# 605565           6
# 605592           4
# 605608           5
# 605609           5
# 605669           5
# 605692           5
# 605693           5
# 605694           4
# 605710           5
# 605720           8
# 605726           5
# 605936           6
# 605945           5
# 605951           5

# %%
app_woe_config['woe'].describe()
# Out:
# count    83951.000000
# mean        -0.009053
# std          0.279553
# min         -1.941600
# 25%         -0.135300
# 50%         -0.020600
# 75%          0.117100
# max          4.206500
# Name: woe, dtype: float64

# %%
app_woe_config.shape
# Out:
# (83951, 11)

# %%
app_woe_config[app_woe_config['level_dist'] > 8]
# Out:
#                                        app_package   bad  order  month_nums  \
# 12287                       call.blacklist.blocker   110    144           3
# 48590                     com.mi.mxmcocoxme.credit    48     65           3
# 57530                     com.prestamos.confiables    44     56           3
# 95870                                            1    70    102           3
# 95871                                          1.0  3856   5629           3
# 95873                                        1.0.0   485    697           3
# 96156                                        1.0.8    51     73           3
# 96169                                        1.0.9    37     55           3
# 96294                                        1.1.3    44     66           3
# 97484                                           11  2833   4027           3
# 99290                                        2.0.1    69    102           3
# 99401                                        2.1.0    42     59           3
# 108092                      call.blacklist.blocker   100    149           3
# 197538                     com.afirme.billu.b.prod   234    315           3
# 210528                com.easypaymoney.qingsongpay   334    418           3
# 276019              air.com.qcreativo.crashpollito   120    128           3
# 278331     camerascanner.photoscanner.pdfconverter   118    130           3
# 285198         com.applaudsoft.wabi.virtual_number    92     97           3
# 307747                          com.jwtian.smartbt   122    134           3
# 307824                     com.kalantos.shakelight   115    122           3
# 360899              air.com.qcreativo.crashpollito   149    156           3
# 365623  com.RoyalArcadeGaming.TinyHeroesAdventures   148    153           3
# 369999         com.applaudsoft.wabi.virtual_number   124    130           3
# 391697                     com.kalantos.shakelight   148    154           3
# 402651                  com.panaustik.revealhidden    93     95           3
# 443966              air.com.qcreativo.crashpollito   149    156           3
# 446231     camerascanner.photoscanner.pdfconverter   148    159           3
# 452829         com.applaudsoft.wabi.virtual_number   124    130           3
# 453938             com.atomic.apps.ringtone.cutter   148    159           3
# 459962                com.csdeveloper.imgconverter   154    160           3
# 474450                     com.kalantos.shakelight   148    157           3
# 494276                com.smarttool.assistivetouch   148    155           3
# 539322        com.cash.credito.prestamo.holapresto    43     57           3
# 541390                               com.cowhi.app    63     83           3
# 545576                             com.esim.numero    48     63           3
# 555880                          com.jwtian.smartbt    39     53           3
# 560022                  com.mediatek.bluetooth.dtt    38     54           3
# 560647                        com.mexico.preferido    68     93           3
# 563326          com.mx.creditoveloz.loan.bank.spei   533    748           3
# 571198                       com.roidapp.photogrid    39     53           3
# 577593                   com.superbox.aos.drop2048    43     61           3
# 584760                                com.yfe.dida    83    115           3
# 644254                        com.oasisfeng.island    79    101           3
# 704839     com.fina.credi.loan.prestamo.bankonline   725    907           3
# 723986                        com.oasisfeng.island   143    182           3
# 729799             com.riteshsahu.SMSBackupRestore    83    102           3
# 814068                        com.oasisfeng.island   278    340           3
# 820827             com.riteshsahu.SMSBackupRestore   206    254           3
# 844353       messages.chat.free.text.messaging.sms   218    279           3
# 916868                        com.oasisfeng.island   242    305           3
# 923978             com.riteshsahu.SMSBackupRestore   188    241           3
# 948110       messages.chat.free.text.messaging.sms   183    241           3
#
#            brate     woe apply_month    woe_bin_freq  level_freq  \
# 12287   0.763889  1.3258     2023-10  (0.415, 1.451]          10
# 48590   0.738462  1.1896     2023-10  (0.415, 1.451]          10
# 57530   0.785714  1.4509     2023-10  (0.415, 1.451]          10
# 95870   0.686275  1.1823     2023-11   (0.39, 1.304]          10
# 95871   0.685024  1.1765     2023-11   (0.39, 1.304]          10
# 95873   0.695839  1.2271     2023-11   (0.39, 1.304]          10
# 96156   0.698630  1.2403     2023-11   (0.39, 1.304]          10
# 96169   0.672727  1.1201     2023-11   (0.39, 1.304]          10
# 96294   0.666667  1.0927     2023-11   (0.39, 1.304]          10
# 97484   0.703501  1.2636     2023-11   (0.39, 1.304]          10
# 99290   0.676471  1.1371     2023-11   (0.39, 1.304]          10
# 99401   0.711864  1.3040     2023-11   (0.39, 1.304]          10
# 108092  0.671141  1.1129     2023-11   (0.39, 1.304]          10
# 197538  0.742857  1.5144     2023-12  (0.408, 1.834]          10
# 210528  0.799043  1.8338     2023-12  (0.408, 1.834]          10
# 276019  0.937500  3.0865     2024-01  (0.501, 3.291]          10
# 278331  0.907692  2.6642     2024-01  (0.501, 3.291]          10
# 285198  0.948454  3.2908     2024-01  (0.501, 3.291]          10
# 307747  0.910448  2.6976     2024-01  (0.501, 3.291]          10
# 307824  0.942623  3.1775     2024-01  (0.501, 3.291]          10
# 360899  0.955128  3.4251     2024-02  (0.535, 4.206]          10
# 365623  0.967320  3.7548     2024-02  (0.535, 4.206]          10
# 369999  0.953846  3.3955     2024-02  (0.535, 4.206]          10
# 391697  0.961039  3.5725     2024-02  (0.535, 4.206]          10
# 402651  0.978947  4.2065     2024-02  (0.535, 4.206]          10
# 443966  0.955128  3.4388     2024-03  (0.539, 3.626]          10
# 446231  0.930818  2.9801     2024-03  (0.539, 3.626]          10
# 452829  0.953846  3.4093     2024-03  (0.539, 3.626]          10
# 453938  0.930818  2.9801     2024-03  (0.539, 3.626]          10
# 459962  0.962500  3.6259     2024-03  (0.539, 3.626]          10
# 474450  0.942675  3.1807     2024-03  (0.539, 3.626]          10
# 494276  0.954839  3.4320     2024-03  (0.539, 3.626]          10
# 539322  0.754386  1.5950     2024-04  (0.473, 1.636]          10
# 541390  0.759036  1.6202     2024-04  (0.473, 1.636]          10
# 545576  0.761905  1.6360     2024-04  (0.473, 1.636]          10
# 555880  0.735849  1.4973     2024-04  (0.473, 1.636]          10
# 560022  0.703704  1.3378     2024-04  (0.473, 1.636]          10
# 560647  0.731183  1.4735     2024-04  (0.473, 1.636]          10
# 563326  0.712567  1.3807     2024-04  (0.473, 1.636]          10
# 571198  0.735849  1.4973     2024-04  (0.473, 1.636]          10
# 577593  0.704918  1.3436     2024-04  (0.473, 1.636]          10
# 584760  0.721739  1.4259     2024-04  (0.473, 1.636]          10
# 644254  0.782178  1.7447     2024-05  (0.446, 1.745]          10
# 704839  0.799338  1.7536     2024-06  (0.449, 1.846]          10
# 723986  0.785714  1.6707     2024-06  (0.449, 1.846]          10
# 729799  0.813725  1.8458     2024-06  (0.449, 1.846]          10
# 814068  0.817647  1.7693     2024-07  (0.412, 1.769]          10
# 820827  0.811024  1.7255     2024-07  (0.412, 1.769]          10
# 844353  0.781362  1.5425     2024-07  (0.412, 1.769]          10
# 916868  0.793443  1.5818     2024-08  (0.425, 1.582]          10
# 923978  0.780083  1.5022     2024-08  (0.425, 1.582]          10
# 948110  0.759336  1.3851     2024-08  (0.425, 1.582]          10
#
#           woe_bin_dist  level_dist
# 12287   (1.306, 1.451]          10
# 48590   (1.161, 1.306]           9
# 57530   (1.306, 1.451]          10
# 95870   (1.174, 1.304]          10
# 95871   (1.174, 1.304]          10
# 95873   (1.174, 1.304]          10
# 96156   (1.174, 1.304]          10
# 96169   (1.043, 1.174]           9
# 96294   (1.043, 1.174]           9
# 97484   (1.174, 1.304]          10
# 99290   (1.043, 1.174]           9
# 99401   (1.174, 1.304]          10
# 108092  (1.043, 1.174]           9
# 197538   (1.467, 1.65]           9
# 210528   (1.65, 1.834]          10
# 276019  (2.962, 3.291]          10
# 278331  (2.633, 2.962]           9
# 285198  (2.962, 3.291]          10
# 307747  (2.633, 2.962]           9
# 307824  (2.962, 3.291]          10
# 360899  (3.365, 3.786]           9
# 365623  (3.365, 3.786]           9
# 369999  (3.365, 3.786]           9
# 391697  (3.365, 3.786]           9
# 402651  (3.786, 4.206]          10
# 443966  (3.263, 3.626]          10
# 446231  (2.901, 3.263]           9
# 452829  (3.263, 3.626]          10
# 453938  (2.901, 3.263]           9
# 459962  (3.263, 3.626]          10
# 474450  (2.901, 3.263]           9
# 494276  (3.263, 3.626]          10
# 539322  (1.472, 1.636]          10
# 541390  (1.472, 1.636]          10
# 545576  (1.472, 1.636]          10
# 555880  (1.472, 1.636]          10
# 560022  (1.309, 1.472]           9
# 560647  (1.472, 1.636]          10
# 563326  (1.309, 1.472]           9
# 571198  (1.472, 1.636]          10
# 577593  (1.309, 1.472]           9
# 584760  (1.309, 1.472]           9
# 644254   (1.57, 1.745]          10
# 704839  (1.661, 1.846]          10
# 723986  (1.661, 1.846]          10
# 729799  (1.661, 1.846]          10
# 814068  (1.592, 1.769]          10
# 820827  (1.592, 1.769]          10
# 844353  (1.415, 1.592]           9
# 916868  (1.424, 1.582]          10
# 923978  (1.424, 1.582]          10
# 948110  (1.265, 1.424]           9

# %%
app_woe_config.to_excel(work_dir/f'app_woe_config_{window_size}.xlsx',index=False)

# %% [markdown]
# ## 每一天的sms数据sender、word的bad数、order数、user数

# %%
def get_words(sms_body):
    """
    获取每行的word
    :param sms_body: df 中的'body'列
    :return: 根据sms_data提取的word
    """

    words =  set(re.compile(r'\b[Ññáéíóú¡a-z]+\b').findall(sms_body.lower()))
    words = words.apply(lambda x: x - stop_words)
    words = words.apply(lambda x:list(filter(lambda x: len(x) > 2, x)))
    words = set(sum(words.tolist(),[]))
    words = list(words)
    return words

# %%
def get_words(sms_data):
    """
    获取每行的word
    :param sms_data: df 中的'sms_data'列
    :return: 根据sms_data提取的word
    """
    if sms_data == '[]' or sms_data == '' or sms_data is None:
        return []
    parse_df = pd.DataFrame(json.loads(sms_data))
    if 'body' not in parse_df.columns:
        print('body not in columns','id:')
        return []

    words = parse_df['body'].apply(lambda x: set(re.compile(r'\b[Ññáéíóú¡a-z]+\b').findall(str(x).lower())))
    words = words.apply(lambda x: x - stop_words)
    words = words.apply(lambda x:list(filter(lambda x: len(x) > 2, x)))
    # print(words)
    words = set(sum(words.tolist(),[]))
    words = list(words)
    return words

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('spanish'))
# 添加自定义停用词
user_stop_words = ['body','phone', 'src_phone', 'read', 'time', 'type']
stop_words.update(user_stop_words)

# %%
def computer_sms_woe_daily(file_path:str,save_path:str):
    try:
        raw_df = pd.read_parquet(file_path) #
        raw_df['apply_month'] = raw_df['apply_time'].dt.strftime('%Y-%m')
        raw_df['bad'] = np.where(raw_df['agr_pd7']==1,raw_df['def_pd7'],None)
        df = raw_df[raw_df['bad'].notnull()]
        if len(df) == 0:
            return 0
        user_word = df[['def_pd7','user_id','bad','apply_month']]
        user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
        user_word = user_word.explode('words')

        tmp_arr = []
        for key,grp in user_word.groupby(['apply_month','words']):
            apply_month,word = key
            rs = {}
            bad = grp['bad'].sum()
            order = grp['bad'].count()
            user = grp['user_id'].nunique()
            rs['apply_month'] = apply_month
            rs['word'] = word
            rs['bad'] = bad
            rs['order'] = order
            rs['user'] = user
            tmp_arr.append(rs)
        df = pd.DataFrame(tmp_arr)
        df.to_parquet(save_path,compression='zstd')
        return 0
    except:
        print(f'{file_path}计算失败 \n', traceback.format_exc())
        return 1

# %%
tmp_dir = work_dir/'sms_tmp' # 设定计算结果保存的路径
if not tmp_dir.exists():
    tmp_dir.mkdir()
file_paths = data_of_dir(raw_dir,['_YM','_M','_AM'])
# 如果tmp_dir/file_name存在，就不再计算
task_list = [ (x,  str(tmp_dir/x.split('/')[-1]) )  for x in file_paths if not (tmp_dir/x.split('/')[-1]).exists() ]  # 生成任务的参数列表,[('/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-16.pqt','/home/mayongzhi/marshall/sender_word_call_app/applist_tmp/raw_YM_2023-08-16.pqt'),  ...]
# 生成任务的参数列表,[('/home/longxiaolei/raw_mx/newcust/raw_YM_2023-08-16.pqt','/home/mayongzhi/marshall/sender_word_call_app/applist_tmp/raw_YM_2023-08-16.pqt'),  ...]

# %%
len(task_list)
# Out:
# 385

# %%
parallel_process(computer_sms_woe_daily,task_list,30)
# Out:
#   9%|▊         | 33/385 [00:18<00:04, 82.97it/s] /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  10%|█         | 40/385 [02:28<36:14,  6.30s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  11%|█         | 41/385 [03:00<44:42,  7.80s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  11%|█         | 43/385 [03:39<52:27,  9.20s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  11%|█▏        | 44/385 [04:04<1:03:14, 11.13s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  12%|█▏        | 45/385 [04:18<1:05:52, 11.62s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  12%|█▏        | 46/385 [04:40<1:15:14, 13.32s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  12%|█▏        | 48/385 [05:05<1:14:37, 13.29s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  13%|█▎        | 50/385 [05:40<1:20:58, 14.50s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  13%|█▎        | 51/385 [05:58<1:24:51, 15.24s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  14%|█▎        | 52/385 [06:10<1:20:01, 14.42s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  14%|█▍        | 54/385 [06:33<1:08:35, 12.43s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  15%|█▌        | 58/385 [06:58<45:55,  8.43s/it]  /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  16%|█▌        | 60/385 [07:29<59:38, 11.01s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  16%|█▌        | 62/385 [07:48<56:08, 10.43s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  16%|█▋        | 63/385 [08:14<1:17:00, 14.35s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  17%|█▋        | 66/385 [08:31<47:23,  8.91s/it]  /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  18%|█▊        | 69/385 [08:35<20:49,  3.95s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  18%|█▊        | 70/385 [08:56<47:08,  8.98s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  18%|█▊        | 71/385 [09:02<42:56,  8.21s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  19%|█▉        | 74/385 [09:24<34:19,  6.62s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  19%|█▉        | 75/385 [09:34<39:36,  7.67s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  20%|██        | 78/385 [09:55<39:20,  7.69s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  21%|██        | 79/385 [10:18<1:01:33, 12.07s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  21%|██        | 80/385 [10:27<56:28, 11.11s/it]  /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  21%|██        | 81/385 [10:30<45:14,  8.93s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  22%|██▏       | 84/385 [10:37<22:49,  4.55s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  22%|██▏       | 86/385 [10:55<31:18,  6.28s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  24%|██▎       | 91/385 [11:10<11:39,  2.38s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  26%|██▌       | 99/385 [11:16<03:59,  1.19it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  27%|██▋       | 104/385 [11:18<03:34,  1.31it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  28%|██▊       | 106/385 [11:26<08:57,  1.93s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  28%|██▊       | 108/385 [11:28<07:16,  1.58s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  28%|██▊       | 109/385 [11:28<05:51,  1.27s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  29%|██▊       | 110/385 [11:31<07:13,  1.58s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  29%|██▉       | 113/385 [11:35<05:31,  1.22s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  30%|███       | 117/385 [11:44<06:23,  1.43s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  31%|███       | 119/385 [11:48<06:58,  1.57s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  32%|███▏      | 122/385 [11:49<03:30,  1.25it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  32%|███▏      | 125/385 [11:52<03:46,  1.15it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  33%|███▎      | 126/385 [11:53<04:01,  1.07it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  33%|███▎      | 127/385 [11:56<06:13,  1.45s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  34%|███▎      | 129/385 [11:58<05:09,  1.21s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  34%|███▍      | 132/385 [12:00<03:32,  1.19it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  35%|███▌      | 136/385 [12:04<02:42,  1.53it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  36%|███▌      | 139/385 [12:07<03:47,  1.08it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  36%|███▋      | 140/385 [12:18<14:46,  3.62s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  37%|███▋      | 141/385 [12:24<17:24,  4.28s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  37%|███▋      | 142/385 [12:28<16:41,  4.12s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  38%|███▊      | 145/385 [12:33<09:12,  2.30s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  38%|███▊      | 146/385 [12:36<09:47,  2.46s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  38%|███▊      | 147/385 [12:43<15:31,  3.91s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  39%|███▉      | 151/385 [12:54<09:42,  2.49s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  39%|███▉      | 152/385 [12:55<07:02,  1.81s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  40%|███▉      | 153/385 [13:01<11:54,  3.08s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  40%|████      | 154/385 [13:09<18:05,  4.70s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  41%|████      | 157/385 [13:15<10:40,  2.81s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  41%|████      | 158/385 [13:20<13:11,  3.49s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  42%|████▏     | 162/385 [13:28<07:55,  2.13s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  42%|████▏     | 163/385 [13:36<14:58,  4.05s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  43%|████▎     | 164/385 [13:43<18:10,  4.93s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  43%|████▎     | 166/385 [13:50<14:07,  3.87s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  94%|█████████▎| 360/385 [22:48<01:22,  3.29s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  94%|█████████▍| 361/385 [22:50<01:05,  2.73s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  95%|█████████▍| 364/385 [22:55<00:44,  2.13s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  95%|█████████▍| 365/385 [22:57<00:39,  1.98s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  96%|█████████▌| 369/385 [23:01<00:18,  1.15s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  96%|█████████▌| 370/385 [23:01<00:13,  1.14it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  96%|█████████▋| 371/385 [23:03<00:15,  1.09s/it]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  97%|█████████▋| 374/385 [23:05<00:08,  1.28it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
#  99%|█████████▊| 380/385 [23:06<00:01,  3.09it/s]/tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# 100%|██████████| 385/385 [23:08<00:00,  3.61s/it]
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# /tmp/ipykernel_42829/59341219.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'words'] = df['sms_data'].apply(get_words)
# 任务完成，总计385个任务,耗时1556.030321598053s

# %%
from concurrent.futures import ProcessPoolExecutor

tmp_dir = work_dir/'sms_tmp'
files = list(tmp_dir.glob('*'))
with ProcessPoolExecutor(16) as executor:
    results = list(tqdm(executor.map(pd.read_parquet, files), total=len(files)))

# 合并所有结果
word_woe_info_20240827 = pd.concat(results, ignore_index=True)

# 进行 groupby 和聚合操作
word_woe_info_20240827 = word_woe_info_20240827.groupby(['apply_month', 'word']).agg({
    'bad': 'sum',
    'order': 'sum',
    'user': 'sum'
}).reset_index()
# Out:
# 100%|██████████| 1214/1214 [00:10<00:00, 115.06it/s]

# %%
word_woe_info_20240827.shape
# Out:
# (11640982, 5)

# %%
word_woe_info_20240827.head()
# Out:
#   apply_month     word  bad  order  user
# 0     2023-01      aaa  961   2580  2580
# 1     2023-01     aaaa  245    570   570
# 2     2023-01    aaaaa  144    314   314
# 3     2023-01   aaaaaa   78    150   150
# 4     2023-01  aaaaaaa   21     43    43

# %%
word_woe_info_20240827[word_woe_info_20240827['word'].str.contains('á')]
# Out:
#          apply_month                   word  bad  order  user
# 73           2023-01  aaaaaáaáaaaaaaaaaaaaa    1      1     1
# 121          2023-01                 aaaaáa    3      3     3
# 287          2023-01                   aacá    1      1     1
# 1055         2023-01                    aaá    0      4     4
# 1056         2023-01                  aaáaa    3      3     3
# ...              ...                    ...  ...    ...   ...
# 11640776     2024-08                  ávila    0      3     3
# 11640777     2024-08                 ávisar    1      1     1
# 11640778     2024-08                  ávise    1      2     2
# 11640779     2024-08                  áviso    1      2     2
# 11640780     2024-08                    áya    1      1     1
#
# [71799 rows x 5 columns]

# %%
word_woe_info_20240827.to_parquet(work_dir/'word_woe_info_20240827.pqt',compression='zstd')

# %%
word_woe_info_20240827 = pd.read_parquet(work_dir/'word_woe_info_20240827.pqt')

# %% [markdown]
# ## sender

# %%
def get_senders(sms_data):
    """
    获取每行的phone
    :param sms_data: df 中的'sms_data'列
    :return:
    """
    # row = pd.DataFrame(row).T
    # print(row)
    # 如果‘sms_data'列为空或者为'[]'，则返回空字典

    if sms_data == '[]' or sms_data == '' or sms_data is None:
        return []
    parse_df = pd.DataFrame(json.loads(sms_data))
    if 'src_phone' not in parse_df.columns:
        print('src_phone not in columns')
        return []
    # if len(parse_df[parse_df['src_phone'].str.len()>20]) > 0:
    #     print(parse_df[parse_df['src_phone'].str.len()>20]['src_phone'])
    parse_df = parse_df[parse_df['src_phone'].str.len() <= 30]
    parse_df['national_phone'] = parse_df['src_phone'].apply(lambda x: normalize_phone(x,'MX'))
    phones = parse_df['national_phone'].tolist()
    return phones

def computer_sender_woe_daily(file_path:str,save_path:str):
    try:
        raw_df = pd.read_parquet(file_path) #
        raw_df['apply_month'] = raw_df['apply_time'].dt.strftime('%Y-%m')
        raw_df['bad'] = np.where(raw_df['agr_pd7']==1,raw_df['def_pd7'],None)
        df = raw_df[raw_df['bad'].notnull()]
        if len(df) == 0:
            return 0
        user_word = df[['def_pd7','user_id','bad','apply_month']]
        user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
        user_word = user_word.explode('senders')

        tmp_arr = []
        for key,grp in user_word.groupby(['apply_month','senders']):
            apply_month, sender = key
            rs = {}
            bad = grp['bad'].sum()
            order = grp['bad'].count()
            user = grp['user_id'].nunique()
            rs['apply_month'] = apply_month
            rs['sender'] = sender
            rs['bad'] = bad
            rs['order'] = order
            rs['user'] = user
            tmp_arr.append(rs)
        df = pd.DataFrame(tmp_arr)
        df.to_parquet(save_path,compression='zstd')
        return 0
    except:
        print(f'{file_path}计算失败 \n', traceback.format_exc())
        return 1

# %%
tmp_dir = work_dir/'sender_tmp' # 设定计算结果保存的路径
if not tmp_dir.exists():
    tmp_dir.mkdir()
file_paths = data_of_dir(raw_dir,['_YM','_M','_AM'])
# 如果tmp_dir/file_name存在，就不再计算
task_list = [ (x,  str(tmp_dir/x.split('/')[-1]) )  for x in file_paths if not (tmp_dir/x.split('/')[-1]).exists() ]  #

# %%
parallel_process(computer_sender_woe_daily,task_list,30)
# Out:
#   2%|▏         | 26/1248 [00:00<00:12, 98.94it/s] /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   3%|▎         | 34/1248 [00:11<09:40,  2.09it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   4%|▍         | 52/1248 [00:17<06:45,  2.95it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▍         | 57/1248 [00:17<04:40,  4.25it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▍         | 59/1248 [00:19<07:44,  2.56it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▍         | 61/1248 [00:22<13:32,  1.46it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▍         | 62/1248 [00:23<13:37,  1.45it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▌         | 63/1248 [00:26<20:27,  1.04s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▌         | 64/1248 [00:29<28:09,  1.43s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▌         | 65/1248 [00:29<22:55,  1.16s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▌         | 67/1248 [00:30<16:16,  1.21it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   5%|▌         | 68/1248 [00:31<18:07,  1.09it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   6%|▌         | 69/1248 [00:31<16:10,  1.22it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   6%|▌         | 74/1248 [00:36<11:40,  1.68it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   6%|▋         | 81/1248 [00:38<04:54,  3.97it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 82/1248 [00:40<14:13,  1.37it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 83/1248 [00:41<17:53,  1.09it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 86/1248 [00:43<14:38,  1.32it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 87/1248 [00:47<31:24,  1.62s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 89/1248 [00:49<21:40,  1.12s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 90/1248 [00:49<20:11,  1.05s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 91/1248 [00:50<17:11,  1.12it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   7%|▋         | 93/1248 [00:51<14:21,  1.34it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 95/1248 [00:55<21:15,  1.11s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 96/1248 [00:58<32:38,  1.70s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 99/1248 [01:00<17:42,  1.08it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 100/1248 [01:00<16:38,  1.15it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 102/1248 [01:01<09:46,  1.95it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   8%|▊         | 106/1248 [01:02<08:08,  2.34it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▊         | 109/1248 [01:04<08:01,  2.37it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▉         | 110/1248 [01:06<15:25,  1.23it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▉         | 111/1248 [01:08<24:18,  1.28s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▉         | 115/1248 [01:10<13:00,  1.45it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▉         | 116/1248 [01:13<21:59,  1.17s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#   9%|▉         | 117/1248 [01:13<19:10,  1.02s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  10%|▉         | 119/1248 [01:14<12:49,  1.47it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  10%|▉         | 120/1248 [01:15<14:15,  1.32it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  10%|█         | 125/1248 [01:20<13:34,  1.38it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  10%|█         | 128/1248 [01:21<08:49,  2.11it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  10%|█         | 130/1248 [01:24<16:00,  1.16it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  11%|█         | 134/1248 [01:26<09:49,  1.89it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# ...
#  11%|█         | 137/1248 [01:28<11:41,  1.58it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  11%|█         | 138/1248 [01:29<15:23,  1.20it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  11%|█         | 139/1248 [01:30<12:55,  1.43it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  11%|█         | 140/1248 [01:30<11:27,  1.61it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  11%|█▏        | 141/1248 [01:36<37:30,  2.03s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  12%|█▏        | 145/1248 [01:36<15:49,  1.16it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  12%|█▏        | 150/1248 [01:38<11:01,  1.66it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  12%|█▏        | 155/1248 [01:39<06:14,  2.92it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  13%|█▎        | 162/1248 [01:44<12:51,  1.41it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  13%|█▎        | 164/1248 [01:47<18:02,  1.00it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  13%|█▎        | 167/1248 [01:52<21:29,  1.19s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  13%|█▎        | 168/1248 [01:52<18:33,  1.03s/it]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  14%|█▎        | 170/1248 [01:54<14:47,  1.21it/s]/tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
# /tmp/ipykernel_42829/3650506456.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_word.loc[:,'senders'] = df['sms_data'].apply(get_senders)
#  14%|█▍        | 172/1248 [02:00<36:33,  2.04s/it]

# %% [markdown]
# ## 滑动窗口计算的woe
